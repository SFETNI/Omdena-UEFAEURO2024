# %% [markdown]
# Lets import libraries for the data reading and visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
league_table = pd.read_csv("/content/League_table2021.csv")

# %%
league_table.head()
# Out:
#    Unnamed: 0  Matches Played  Wins  Draws  Losses  Goals For  Goals Against  \
# 0           0             7.0   5.0    2.0     0.0       13.0            4.0
# 1           1             7.0   5.0    2.0     0.0       11.0            2.0
# 2           2             NaN   NaN    NaN     NaN        NaN            NaN
# 3           3             6.0   2.0    4.0     0.0       13.0            6.0
# 4           4             6.0   3.0    0.0     3.0       12.0            7.0
#
#    Goal Diff.   Pts  exp. Goals  exp. Goals Allowed  exp. Goals Diff.  xGD/90
# 0         9.0  17.0        13.1                 6.0               7.2    1.02
# 1         9.0  17.0        11.0                 5.4               5.7    0.81
# 2         NaN   NaN         NaN                 NaN               NaN     NaN
# 3         7.0  10.0        16.7                 7.4               9.3    1.54
# 4         5.0   9.0         9.9                 7.1               2.8    0.47

# %% [markdown]
# As the data suggests there are:
#
#
# *   Match played - how many mathces have been played
# *   Wins - how many matches were winned
# *   Draws - how many matches were draws
# *   Losses - how many matches were lost game
# *   Goals For - For How many goals were
# *   Goals Against - The quantity of the against goals
# *   Pts - The points got quantity
# *   exp.Goals - Expected Goals how many have to be
# *   exp.Goals Allowed - as it says expected allowed goals
# *   exp.Goals Diff - as it says expected fifference of  goals
# *   xGD/90 - In 90 minutes got information.

# %% [markdown]
# Lets Give first the paiplot of the data

# %%
plt.plot(figsize=(16,6))
sns.pairplot(data=league_table,diag_kind='kde')

# %% [markdown]
# The droping of the 0 from the data and the NaN as well

# %%
league_table = league_table.dropna()

# %%
league_table
# Out:
#     Unnamed: 0  Matches Played  Wins  Draws  Losses  Goals For  Goals Against  \
# 0            0             7.0   5.0    2.0     0.0       13.0            4.0
# 1            1             7.0   5.0    2.0     0.0       11.0            2.0
# 3            3             6.0   2.0    4.0     0.0       13.0            6.0
# 4            4             6.0   3.0    0.0     3.0       12.0            7.0
# 6            6             5.0   4.0    0.0     1.0        9.0            3.0
# 7            7             5.0   2.0    1.0     2.0        6.0            4.0
# 8            8             5.0   1.0    3.0     1.0        8.0            9.0
# 9            9             5.0   2.0    0.0     3.0        6.0           10.0
# 11          11             4.0   3.0    0.0     1.0        8.0            4.0
# 12          12             4.0   2.0    1.0     1.0        5.0            4.0
# 13          13             4.0   1.0    3.0     0.0        7.0            6.0
# ...

# %% [markdown]
# Lets do some predictions for the match played part

# %%
x = league_table.drop(['Matches Played'],axis=1)
y = league_table['Matches Played']

# %%
#importing the train_test split from the scikit_learn
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=5)

# %% [markdown]
# The first one for classification lets take the RandomForestClassifier

# %%
from sklearn.ensemble import RandomForestClassifier
randclass = RandomForestClassifier(n_estimators = 20, random_state = 0)
randclass.fit(X_train,Y_train)
y_pred = randclass.predict(X_test)

# %% [markdown]
# Second Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(max_iter=4)
log.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(max_iter=4)

# %% [markdown]
# Third SVM

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC()
svc.fit(X_train,Y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py:1244: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC()

# %% [markdown]
# 4TH Decision tree

# %%
from sklearn import tree
treeclass = tree.DecisionTreeClassifier()
treeclass = treeclass.fit(X_train, Y_train)

# %%
#import classifiction report part and making model
from sklearn.metrics import classification_report
def report(model):
    preds = model.predict(X_test)
    print(classification_report(Y_test,preds))

# %%
print("Random Forest")
report(randclass)
ConfusionMatrixDisplay.from_predictions(Y_test, y_pred)
plt.show()
# Out:
# Random Forest
#               precision    recall  f1-score   support
#
#          3.0       1.00      1.00      1.00         5
#          4.0       1.00      1.00      1.00         2
#          6.0       0.00      0.00      0.00         1
#          7.0       0.00      0.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.50      0.50         8
# weighted avg       0.88      0.88      0.88         8
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print("Logistic Regression")
report(log)
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(Y_test, y_pred)
plt.show()
# Out:
# Logistic Regression
#               precision    recall  f1-score   support
#
#          3.0       1.00      1.00      1.00         5
#          4.0       1.00      1.00      1.00         2
#          6.0       0.00      0.00      0.00         1
#          7.0       0.00      0.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.50      0.50         8
# weighted avg       0.88      0.88      0.88         8
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
print("SVC")
report(svc)
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_predictions(Y_test, y_pred)
plt.show()
# Out:
# SVC
#               precision    recall  f1-score   support
#
#          3.0       1.00      1.00      1.00         5
#          4.0       0.67      1.00      0.80         2
#          6.0       0.00      0.00      0.00         1
#
#     accuracy                           0.88         8
#    macro avg       0.56      0.67      0.60         8
# weighted avg       0.79      0.88      0.82         8
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print("Decition tree")
report(treeclass)
ConfusionMatrixDisplay.from_predictions(Y_test, y_pred)
plt.show()
# Out:
# Decition tree
#               precision    recall  f1-score   support
#
#          3.0       1.00      0.80      0.89         5
#          4.0       0.67      1.00      0.80         2
#          6.0       1.00      1.00      1.00         1
#
#     accuracy                           0.88         8
#    macro avg       0.89      0.93      0.90         8
# weighted avg       0.92      0.88      0.88         8

# %%
# plot tree
plt.figure(figsize=(50,50))  # set plot size (denoted in inches)
tree.plot_tree(treeclass, fontsize=20)
plt.show()

# %% [markdown]
# Here is thellnear regression for the model and getting there mean_sqaure error

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
reg.score(X_train,Y_train)
# Out:
# 1.0

# %% [markdown]
# Lets get the coefficients on the linear regresion as well

# %%
reg.coef_
# Out:
# array([ 2.08757505e-16, -9.09090909e-02,  6.36363636e-01,  1.00000000e+00,
#         3.12250226e-17,  5.09141340e-16,  3.46944695e-16,  3.63636364e-01,
#         4.55885329e-15, -5.06409151e-15, -5.08273978e-15,  1.84314369e-16])

# %%
reg.intercept_
# Out:
# -7.105427357601002e-15

# %%
reg_predictions = reg.predict(X_test)

# %%
reg_predictions
# Out:
# array([3., 6., 3., 3., 3., 3., 4., 4.])

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
MAE = mean_absolute_error(Y_test,reg_predictions)
MSE = mean_squared_error(Y_test,reg_predictions)
RMSE = np.sqrt(MSE)

# %%
print("MAE: ",MAE)
print("MSE: ",MSE)
print("RMSE: ",RMSE)
# Out:
# MAE:  7.771561172376096e-16
# MSE:  1.1832913578315177e-30
# RMSE:  1.0877919644084146e-15

# %%
Residuals = Y_test - reg_predictions

# %% [markdown]
# Correlation of the data

# %%
league_table.corr()
# Out:
#                     Unnamed: 0  Matches Played      Wins     Draws    Losses  \
# Unnamed: 0            1.000000       -0.947232 -0.867064 -0.392097  0.544680
# Matches Played       -0.947232        1.000000  0.851748  0.423079 -0.489416
# Wins                 -0.867064        0.851748  1.000000  0.077752 -0.499865
# Draws                -0.392097        0.423079  0.077752  1.000000 -0.745959
# Losses                0.544680       -0.489416 -0.499865 -0.745959  1.000000
# Goals For            -0.916108        0.912387  0.772653  0.485493 -0.556937
# Goals Against         0.324732       -0.264854 -0.553208 -0.037696  0.538338
# Goal Diff.           -0.889148        0.859911  0.872149  0.412393 -0.689735
# Pts                  -0.920483        0.913560  0.969389  0.320159 -0.658704
# exp. Goals           -0.817309        0.852153  0.641463  0.590723 -0.560399
# exp. Goals Allowed   -0.146993        0.209872 -0.100019  0.246629  0.133690
# ...

# %% [markdown]
# 5th model is AdaBosst algorythm

# %%
from sklearn.ensemble import AdaBoostClassifier
adaboost=AdaBoostClassifier(n_estimators=100,random_state=0)
adaboost.fit(X_train,Y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=0)

# %%
print("Ada boost")
report(adaboost)
ConfusionMatrixDisplay.from_predictions(Y_test, y_pred)
# Out:
# Ada boost
#               precision    recall  f1-score   support
#
#          3.0       1.00      0.60      0.75         5
#          4.0       0.50      1.00      0.67         2
#          5.0       0.00      0.00      0.00         0
#          6.0       0.00      0.00      0.00         1
#
#     accuracy                           0.62         8
#    macro avg       0.38      0.40      0.35         8
# weighted avg       0.75      0.62      0.64         8
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %% [markdown]
# 6th one is gradient Boost Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
gradboost = GradientBoostingClassifier()
gradboost.fit(X_train,Y_train)
# Out:
# GradientBoostingClassifier()

# %%
print("Gradient  boost")
report(gradboost)
ConfusionMatrixDisplay.from_predictions(Y_test,y_pred)
plt.show()
# Out:
# Gradient  boost
#               precision    recall  f1-score   support
#
#          3.0       1.00      1.00      1.00         5
#          4.0       1.00      1.00      1.00         2
#          6.0       0.00      0.00      0.00         1
#          7.0       0.00      0.00      0.00         0
#
#     accuracy                           0.88         8
#    macro avg       0.50      0.50      0.50         8
# weighted avg       0.88      0.88      0.88         8
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(Residuals,reg_predictions)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')  # Line for perfect predictions
plt.title('Residuals VS Regresion prediction')
plt.xlabel('Regression prediction')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# As we  can see lets give all algorythm precision with accurancy
#
# 1.   Random Forest Classifier Precision is 1 and Accuracy is 0.88
# 2.   Logistic Regresion is Precision 1 and the Accuracy is 0.88
# 3. SMV Precision 1 Accuracy 0.88
# 4. Decision tree is Precision 1 Accuracy is 0.88
# 5. Ada bosst Classifier the Precision is 1 and the Accuracy is 0.62
# 6. Gradiant boost Classifier the Precision is 1 and the Accuracy is 1.0 as well

# %% [markdown]
# As we can give as well the linear part is this:
# 1. MAE:  7.771561172376096e-16
# 2. MSE:  1.1832913578315177e-30
# 3. RMSE:  1.0877919644084146e-15

# %% [markdown]
# As the data gave the regression predition and the tested part for the residuals isn't good
