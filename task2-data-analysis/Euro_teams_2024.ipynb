# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
euro_teams2024 = pd.read_csv("/content/euro_24_teams.csv")

# %%
euro_teams2024.head()
# Out:
#              team  year  comp  fifa_ranking  mkt_val  avg_mkt_val  avg_age  \
# 0         Albania  2024  Euro            66    111.5         4.13    27.00
# 1         Austria  2024  Euro            25    237.0         9.12    26.81
# 2         Belgium  2024  Euro             3    584.5        23.38    26.88
# 3         Croatia  2024  Euro            10    327.7        12.60    27.69
# 4  Czech Republic  2024  Euro            36    187.9         7.23    25.50
#
#    goalie_mkt_val  goalie_age  def_mean_age  def_mkt_val  def_mean_mkt_val  \
# 0             3.0          29         27.67         29.9              3.32
# 1             3.0          27         26.25         80.3             10.04
# 2             7.0          32         28.13         92.0             11.50
# 3            11.0          30         26.38        144.2             18.03
# 4             7.0          24         25.13         55.2              6.90
#
# ...

# %%
euro_teams2024.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   team              24 non-null     object
#  1   year              24 non-null     int64
#  2   comp              24 non-null     object
#  3   fifa_ranking      24 non-null     int64
#  4   mkt_val           24 non-null     float64
#  5   avg_mkt_val       24 non-null     float64
#  6   avg_age           24 non-null     float64
#  7   goalie_mkt_val    24 non-null     float64
#  8   goalie_age        24 non-null     int64
#  9   def_mean_age      24 non-null     float64
#  10  def_mkt_val       24 non-null     float64
#  11  def_mean_mkt_val  24 non-null     float64
#  12  mid_mean_age      24 non-null     float64
#  13  mid_mkt_val       24 non-null     float64
#  14  mid_mean_mkt_val  24 non-null     float64
#  15  att_mean_age      24 non-null     float64
# ...

# %%
euro_teams2024.isnull().sum()
# Out:
# team                0
# year                0
# comp                0
# fifa_ranking        0
# mkt_val             0
# avg_mkt_val         0
# avg_age             0
# goalie_mkt_val      0
# goalie_age          0
# def_mean_age        0
# def_mkt_val         0
# def_mean_mkt_val    0
# mid_mean_age        0
# mid_mkt_val         0
# mid_mean_mkt_val    0
# att_mean_age        0
# att_mkt_val         0
# att_mean_mkt_val    0
# dtype: int64

# %%
euro_teams2024.isna().sum()
# Out:
# team                0
# year                0
# comp                0
# fifa_ranking        0
# mkt_val             0
# avg_mkt_val         0
# avg_age             0
# goalie_mkt_val      0
# goalie_age          0
# def_mean_age        0
# def_mkt_val         0
# def_mean_mkt_val    0
# mid_mean_age        0
# mid_mkt_val         0
# mid_mean_mkt_val    0
# att_mean_age        0
# att_mkt_val         0
# att_mean_mkt_val    0
# dtype: int64

# %%
euro_teams2024.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Lets do some stistical analysis give the value counting of all the data has been provided

# %%
euro_teams2024['att_mean_age'].value_counts()
# Out:
# att_mean_age
# 26.00    4
# 26.50    2
# 27.00    2
# 26.14    2
# 29.29    1
# 25.14    1
# 24.88    1
# 27.63    1
# 26.13    1
# 27.83    1
# 27.80    1
# 29.50    1
# 26.25    1
# 26.71    1
# 24.86    1
# 26.63    1
# 23.88    1
# 26.57    1
# Name: count, dtype: int64

# %%
euro_teams2024['att_mean_mkt_val'].value_counts()
# Out:
# att_mean_mkt_val
# 17.50    2
# 5.70     1
# 26.50    1
# 8.94     1
# 36.14    1
# 10.17    1
# 3.10     1
# 5.80     1
# 3.45     1
# 44.57    1
# 6.25     1
# 22.67    1
# 6.60     1
# 4.88     1
# 29.33    1
# 12.92    1
# 59.75    1
# 87.86    1
# 19.25    1
# 7.23     1
# 5.07     1
# 37.71    1
# 11.81    1
# Name: count, dtype: int64

# %%
euro_teams2024['att_mkt_val'].value_counts()
# Out:
# att_mkt_val
# 122.50    2
# 34.20     1
# 159.00    1
# 71.50     1
# 253.00    1
# 61.00     1
# 21.70     1
# 29.00     1
# 27.60     1
# 312.00    1
# 37.50     1
# 136.00    1
# 33.00     1
# 19.50     1
# 176.00    1
# 103.35    1
# 478.00    1
# 615.00    1
# 154.00    1
# 63.70     1
# 35.50     1
# 264.00    1
# 94.50     1
# Name: count, dtype: int64

# %%
euro_teams2024['avg_age'].value_counts()
# Out:
# avg_age
# 27.00    4
# 27.69    3
# 27.38    2
# 26.88    2
# 25.50    1
# 26.08    1
# 27.15    1
# 28.54    1
# 26.81    1
# 26.50    1
# 26.36    1
# 27.81    1
# 28.27    1
# 27.27    1
# 27.31    1
# 25.81    1
# 26.35    1
# Name: count, dtype: int64

# %%
euro_teams2024['fifa_ranking'].value_counts()
# Out:
# fifa_ranking
# 66    1
# 25    1
# 40    1
# 19    1
# 8     1
# 57    1
# 48    1
# 33    1
# 39    1
# 46    1
# 6     1
# 28    1
# 7     1
# 9     1
# 26    1
# 16    1
# 75    1
# 2     1
# 4     1
# 21    1
# 36    1
# 10    1
# 3     1
# 22    1
# Name: count, dtype: int64

# %%
euro_teams2024['comp'].value_counts()
# Out:
# comp
# Euro    24
# Name: count, dtype: int64

# %%
euro_teams2024['def_mean_age'].value_counts()
# Out:
# def_mean_age
# 27.67    1
# 26.25    1
# 26.00    1
# 28.00    1
# 29.75    1
# 26.75    1
# 27.88    1
# 28.25    1
# 27.90    1
# 27.50    1
# 27.00    1
# 27.71    1
# 27.38    1
# 26.30    1
# 27.80    1
# 27.33    1
# 29.57    1
# 26.50    1
# 28.67    1
# 28.44    1
# 25.13    1
# 26.38    1
# 28.13    1
# 25.60    1
# Name: count, dtype: int64

# %%
euro_teams2024['team'].value_counts()
# Out:
# team
# Albania           1
# Austria           1
# Turkiye           1
# Switzerland       1
# Spain             1
# Slovenia          1
# Slovakia          1
# Serbia            1
# Scotland          1
# Romania           1
# Portugal          1
# Poland            1
# Netherlands       1
# Italy             1
# Hungary           1
# Germany           1
# Georgia           1
# France            1
# England           1
# Denmark           1
# Czech Republic    1
# Croatia           1
# Belgium           1
# Ukraine           1
# Name: count, dtype: int64

# %%
# Convert 'date' to datetime format
euro_teams2024['year'] = pd.to_datetime(euro_teams2024['year'])
euro_teams2024.head(5)
# Out:
#              team                          year  comp  fifa_ranking  mkt_val  \
# 0         Albania 1970-01-01 00:00:00.000002024  Euro            66    111.5
# 1         Austria 1970-01-01 00:00:00.000002024  Euro            25    237.0
# 2         Belgium 1970-01-01 00:00:00.000002024  Euro             3    584.5
# 3         Croatia 1970-01-01 00:00:00.000002024  Euro            10    327.7
# 4  Czech Republic 1970-01-01 00:00:00.000002024  Euro            36    187.9
#
#    avg_mkt_val  avg_age  goalie_mkt_val  goalie_age  def_mean_age  \
# 0         4.13    27.00             3.0          29         27.67
# 1         9.12    26.81             3.0          27         26.25
# 2        23.38    26.88             7.0          32         28.13
# 3        12.60    27.69            11.0          30         26.38
# 4         7.23    25.50             7.0          24         25.13
#
#    def_mkt_val  def_mean_mkt_val  mid_mean_age  mid_mkt_val  mid_mean_mkt_val  \
# ...

# %% [markdown]
# Data Visualizations

# %%
#Distribution of the teams by ranking
plt.figure(figsize=(10, 6))
sns.histplot(euro_teams2024['fifa_ranking'], bins=45, kde=True)
plt.title('Distribution of Fifa ranking')
plt.xlabel('Fifa Ranking')
plt.ylabel('Frequency')
plt.show()

# %%
# Assuming 'euro team' is your DataFrame
euro_team2024_counts =euro_teams2024 ['mkt_val']
plt.figure(figsize=(8, 6))
plt.bar(euro_team2024_counts.index,euro_team2024_counts, color='green')
plt.title('Market value of the over all teams')
plt.xlabel('Market value')
plt.ylabel('Count')
plt.show()

# %%
# Create a pivot table
euro_team2024_counts = euro_teams2024.pivot_table(index='team',columns='mkt_val',aggfunc='size', fill_value=0)

# Create a heatmap
sns.heatmap(euro_team2024_counts,cmap='Greens',annot=False)
plt.title('Heatmap of Team market value')
plt.ylabel('Team')
plt.xlabel('Market Value')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# Lets see the age of the team players

# %%
euro_teams2024['goalie_age'].value_counts()
# Out:
# goalie_age
# 24    4
# 27    3
# 28    3
# 32    2
# 30    2
# 23    2
# 34    2
# 25    2
# 29    1
# 21    1
# 31    1
# 35    1
# Name: count, dtype: int64

# %%
# Create a pivot table
euro_team2024_counts = euro_teams2024.pivot_table(index='team',columns='goalie_age',aggfunc='size', fill_value=0)

# Create a heatmap
sns.heatmap(euro_team2024_counts,cmap='Greens',annot=False)
plt.title('Heatmap of Team goal age of the members')
plt.ylabel('Team')
plt.xlabel('Market Value')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# Lets give pairplots of all data

# %%
sns.pairplot(data=euro_teams2024)

# %% [markdown]
# Making the correletion heatmap of the data

# %%
euro_teams2024_numerical = euro_teams2024.drop(columns=['team','comp'],axis=1)

# %%
sns.heatmap(euro_teams2024_numerical.corr(), fmt='.2f', cmap='Pastel2', linewidths=1)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# Making all the same type of values

# %%
euro_teams2024_numerical = euro_teams2024_numerical.astype(int)

# %% [markdown]
# Lets do some clustering for the exploratory data analysis

# %%
#lets do the clustering exploratory data analasys
from sklearn.cluster import KMeans
clusters = 12

kmeans = KMeans(n_clusters = clusters)
kmeans.fit(euro_teams2024_numerical)

print(kmeans.labels_)
# Out:
# [ 2 10  6  9 10  0  4  1  2  3 10  8  3 10  5  2 10 11  2  2  7 11 11  0]
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#some PCA as well
from sklearn.decomposition import PCA

pca = PCA(5)
pca.fit(euro_teams2024_numerical)

pca_data = pd.DataFrame(pca.transform(euro_teams2024_numerical))

print(pca_data.head())
# Out:
#             0          1          2          3          4
# 0 -412.486854  25.459342 -10.797786  12.509503 -19.116286
# 1 -266.753989 -34.139641 -27.523846 -12.650443  -3.569704
# 2  143.250745  96.170012 -29.096752 -30.055991   8.061917
# 3 -170.033288 -77.374049  10.330039 -16.153663   2.931878
# 4 -327.353017  24.089454   8.586274  -5.419191  -0.583873

# %% [markdown]
# K_means clustering Visuals

# %%
sns.scatterplot(kmeans.labels_)
# Out:
# <Axes: >

# %%
sns.barplot(data=kmeans.labels_)
# Out:
# <Axes: >

# %%
sns.kdeplot(data=kmeans.labels_)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# Visualizations of the PCA

# %%
sns.heatmap(pca_data,annot=True)
# Out:
# <Axes: >

# %%
sns.scatterplot(pca_data)
# Out:
# <Axes: >

# %%
sns.kdeplot(pca_data)
# Out:
# <Axes: ylabel='Density'>

# %%
sns.pairplot(data=pca_data)

# %%
max=euro_teams2024_numerical.max()
print('Maximum:',max)
# Out:
# Maximum: year                2024
# fifa_ranking          75
# mkt_val             1520
# avg_mkt_val           58
# avg_age               28
# goalie_mkt_val        40
# goalie_age            35
# def_mean_age          29
# def_mkt_val          359
# def_mean_mkt_val      44
# mid_mean_age          29
# mid_mkt_val          565
# mid_mean_mkt_val      80
# att_mean_age          29
# att_mkt_val          615
# att_mean_mkt_val      87
# dtype: int64

# %%
min=euro_teams2024_numerical.min()
print('Minimum:',min)
# Out:
# Minimum: year                2024
# fifa_ranking           2
# mkt_val               92
# avg_mkt_val            3
# avg_age               25
# goalie_mkt_val         2
# goalie_age            21
# def_mean_age          25
# def_mkt_val            6
# def_mean_mkt_val       0
# mid_mean_age          22
# mid_mkt_val           13
# mid_mean_mkt_val       1
# att_mean_age          23
# att_mkt_val           19
# att_mean_mkt_val       3
# dtype: int64

# %%
mean =euro_teams2024_numerical.mean()
print('Avergae:',mean)
# Out:
# Avergae: year                2024.000000
# fifa_ranking          26.916667
# mkt_val              473.041667
# avg_mkt_val           17.958333
# avg_age               26.625000
# goalie_mkt_val        16.416667
# goalie_age            27.708333
# def_mean_age          26.958333
# def_mkt_val          128.250000
# def_mean_mkt_val      14.791667
# mid_mean_age          25.958333
# mid_mkt_val          169.458333
# mid_mean_mkt_val      22.083333
# att_mean_age          26.125000
# att_mkt_val          142.416667
# att_mean_mkt_val      19.916667
# dtype: float64

# %% [markdown]
# As we can considarable see the for the maximum and the minimum values of each the data is given as well as the Avergare for the 2024 year euro rankings

# %%
euro_teams2024.describe()
# Out:
#                                 year  fifa_ranking      mkt_val  avg_mkt_val  \
# count                             24     24.000000    24.000000    24.000000
# mean   1970-01-01 00:00:00.000002024     26.916667   473.388750    18.372083
# min    1970-01-01 00:00:00.000002024      2.000000    92.130000     3.540000
# 25%    1970-01-01 00:00:00.000002024      8.750000   182.087500     7.005000
# 50%    1970-01-01 00:00:00.000002024     23.500000   318.450000    12.250000
# 75%    1970-01-01 00:00:00.000002024     39.250000   720.375000    27.997500
# max    1970-01-01 00:00:00.000002024     75.000000  1520.000000    58.270000
# std                              NaN     20.593196   395.497118    15.432302
#
#         avg_age  goalie_mkt_val  goalie_age  def_mean_age  def_mkt_val  \
# count  24.00000       24.000000   24.000000     24.000000    24.000000
# mean   27.05625       16.437500   27.708333     27.412083   128.554167
# ...

# %%
# Create a pivot table
euro_team2024_counts = euro_teams2024.pivot_table(index='team',columns='goalie_mkt_val',aggfunc='size', fill_value=0)

# Create a heatmap
sns.heatmap(euro_team2024_counts,cmap='Greens',annot=False)
plt.title('Heatmap of Team goal market value')
plt.ylabel('Team')
plt.xlabel('Market Value')
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# As of with the less market value of goals as wee can see highest rank gives the teams as are onlu one as on market value of 2.5 is Scotland.

# %% [markdown]
# The maximum max value Mraket is Italy and Poland on 40.0

# %%
#Here is one of the issentiols are the XGBOost part for the predicting arts as well as for testing and the residuals
import xgboost as xg
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import train_test_split

# %%
X, y = euro_teams2024_numerical.iloc[:, :-1], euro_teams2024_numerical.iloc[:, -1]

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y,
                      test_size = 0.3, random_state = 7)

# %%
xgb_r = xg.XGBRegressor(objective ='reg:linear',
                  n_estimators = 10, seed = 7)

# %%
# Fitting the model
xgb_r.fit(train_X, train_y)

# Predict the model
pred = xgb_r.predict(test_X)

# RMSE Computation
rmse = np.sqrt(MSE(test_y, pred))
print("RMSE : % f" %(rmse))
# Out:
# RMSE :  5.986699
# /usr/local/lib/python3.10/dist-packages/xgboost/core.py:160: UserWarning: [10:56:34] WARNING: /workspace/src/objective/regression_obj.cu:209: reg:linear is now deprecated in favor of reg:squarederror.
#   warnings.warn(smsg, UserWarning)

# %%
residuals = test_y - pred

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(residuals,pred)
plt.plot([y.min(), y.max()], [y.min(), y.max()], 'r--')  # Line for perfect predictions
plt.title('Residuals VS Pred')
plt.xlabel('Pred')
plt.ylabel('Residuals')
plt.show()

# %% [markdown]
# As the residuals gives it's good not overfitted and less even

# %%
euro_teams2024_numerical.to_csv("/content/Euro_24_teams.csv")
