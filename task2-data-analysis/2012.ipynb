# %%
# !git clone https://dagshub.com/Omdena/TunisiaLocalChapter_UEFAEURO2024.git
# Out:
# Cloning into 'TunisiaLocalChapter_UEFAEURO2024'...
# remote: Enumerating objects: 739, done.
# remote: Counting objects: 100% (739/739), done.
# remote: Compressing objects: 100% (731/731), done.
# remote: Total 739 (delta 428), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (739/739), 49.70 MiB | 6.47 MiB/s, done.
# Resolving deltas: 100% (428/428), done.

# %%
cd TunisiaLocalChapter_UEFAEURO2024
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024

# %%
ls
# Out:
# Datasets/                        task2-data-analysis/
# EDA_match_team_statistics.ipynb  task3-machine-learning-modeling/
# README.md                        task4-tournament-impact-on-tourism/
# task1-data-collection/

# %%
cd Datasets
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets

# %%
ls
# Out:
#  archive/                                          match_events.csv
#  archive.zip                                       match_information.csv
#  cleaned_euro_football.csv                         match_line_ups.csv
#  euro2024_player_rankings.csv                      match_team_statistics.csv
#  euro2024_players.csv                              players_stats_uefa_scraper.csv
#  euro_cup_datasets.zip                             pre_match_information.csv
#  fifa_ranking-2024-04-04.csv                       README.md
#  FIFA_rankings_1992_2024.zip                       results.csv
# 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'   Upload/
#  international_results-master.zip

# %%
cd 'Football - Soccer - UEFA EURO, 1960 - 2024'
# Out:
# [Errno 2] No such file or directory: 'Football - Soccer - UEFA EURO, 1960 - 2024'
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets

# %%
# prompt: unzip 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'

# !unzip 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'
# Out:
# Archive:  Football - Soccer - UEFA EURO, 1960 - 2024.zip
#   inflating: euro_summary.csv
#   inflating: matches/matches/euro/1960.csv
#   inflating: matches/matches/euro/1964.csv
#   inflating: matches/matches/euro/1968.csv
#   inflating: matches/matches/euro/1972.csv
#   inflating: matches/matches/euro/1976.csv
#   inflating: matches/matches/euro/1980.csv
#   inflating: matches/matches/euro/1984.csv
#   inflating: matches/matches/euro/1988.csv
#   inflating: matches/matches/euro/1992.csv
#   inflating: matches/matches/euro/1996.csv
#   inflating: matches/matches/euro/2000.csv
#   inflating: matches/matches/euro/2004.csv
#   inflating: matches/matches/euro/2008.csv
#   inflating: matches/matches/euro/2012.csv
#   inflating: matches/matches/euro/2016.csv
#   inflating: matches/matches/euro/2020.csv
#   inflating: matches/matches/euro/2024.csv
#   inflating: matches/matches/friendly_2021-2024.csv
#   inflating: matches/matches/nations/2019.csv
#   inflating: matches/matches/nations/2021.csv
#   inflating: matches/matches/nations/2023.csv
#   inflating: matches/matches/qualifying_1960-2024.csv

# %%
ls
# Out:
#  archive/                                          matches/
#  archive.zip                                       match_events.csv
#  cleaned_euro_football.csv                         match_information.csv
#  euro2024_player_rankings.csv                      match_line_ups.csv
#  euro2024_players.csv                              match_team_statistics.csv
#  euro_cup_datasets.zip                             players_stats_uefa_scraper.csv
#  euro_summary.csv                                  pre_match_information.csv
#  fifa_ranking-2024-04-04.csv                       README.md
#  FIFA_rankings_1992_2024.zip                       results.csv
# 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'   Upload/
#  international_results-master.zip

# %%
cd matches
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches

# %%
ls
# Out:
# matches/

# %%
cd matches
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches/matches

# %%
ls
# Out:
# euro/  friendly_2021-2024.csv  nations/  qualifying_1960-2024.csv

# %%
cd euro
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches/matches/euro

# %%
ls
# Out:
# 1960.csv  1968.csv  1976.csv  1984.csv  1992.csv  2000.csv  2008.csv  2016.csv  2024.csv
# 1964.csv  1972.csv  1980.csv  1988.csv  1996.csv  2004.csv  2012.csv  2020.csv

# %%
import pandas as pd
df = pd.read_csv("/content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches/matches/euro/2012.csv")
df
# Out:
#               home_team            away_team home_team_code away_team_code  \
# 0                 Spain                Italy            ESP            ITA
# 1               Germany                Italy            GER            ITA
# 2              Portugal                Spain            POR            ESP
# 3               England                Italy            ENG            ITA
# 4                 Spain               France            ESP            FRA
# 5               Germany               Greece            GER            GRE
# 6               Czechia             Portugal            CZE            POR
# 7                Sweden               France            SWE            FRA
# 8               England              Ukraine            ENG            UKR
# 9                 Italy  Republic of Ireland            ITA            IRL
# 10              Croatia                Spain            CRO            ESP
# 11              Denmark              Germany            DEN            GER
# 12             Portugal          Netherlands            POR            NED
# 13               Greece               Russia            GRE            RUS
# 14              Czechia               Poland            CZE            POL
# 15               Sweden              England            SWE            ENG
# 16              Ukraine               France            UKR            FRA
# 17                Spain  Republic of Ireland            ESP            IRL
# 18                Italy              Croatia            ITA            CRO
# 19          Netherlands              Germany            NED            GER
# 20              Denmark             Portugal            DEN            POR
# 21               Poland               Russia            POL            RUS
# 22               Greece              Czechia            GRE            CZE
# 23              Ukraine               Sweden            UKR            SWE
# 24               France              England            FRA            ENG
# 25  Republic of Ireland              Croatia            IRL            CRO
# 26                Spain                Italy            ESP            ITA
# 27              Germany             Portugal            GER            POR
# 28          Netherlands              Denmark            NED            DEN
# 29               Russia              Czechia            RUS            CZE
# 30               Poland               Greece            POL            GRE
#
#     home_score  away_score  home_penalty  away_penalty  home_score_total  \
# 0          4.0         0.0           NaN           NaN               4.0
# 1          1.0         2.0           NaN           NaN               1.0
# 2          0.0         0.0           2.0           4.0               0.0
# 3          0.0         0.0           2.0           4.0               0.0
# 4          2.0         0.0           NaN           NaN               2.0
# 5          4.0         2.0           NaN           NaN               4.0
# 6          0.0         1.0           NaN           NaN               0.0
# 7          2.0         0.0           NaN           NaN               2.0
# 8          1.0         0.0           NaN           NaN               1.0
# 9          2.0         0.0           NaN           NaN               2.0
# 10         0.0         1.0           NaN           NaN               0.0
# 11         1.0         2.0           NaN           NaN               1.0
# 12         2.0         1.0           NaN           NaN               2.0
# 13         1.0         0.0           NaN           NaN               1.0
# 14         1.0         0.0           NaN           NaN               1.0
# 15         2.0         3.0           NaN           NaN               2.0
# 16         0.0         2.0           NaN           NaN               0.0
# 17         4.0         0.0           NaN           NaN               4.0
# 18         1.0         1.0           NaN           NaN               1.0
# 19         1.0         2.0           NaN           NaN               1.0
# 20         2.0         3.0           NaN           NaN               2.0
# 21         1.0         1.0           NaN           NaN               1.0
# 22         1.0         2.0           NaN           NaN               1.0
# 23         2.0         1.0           NaN           NaN               2.0
# 24         1.0         1.0           NaN           NaN               1.0
# 25         1.0         3.0           NaN           NaN               1.0
# 26         1.0         1.0           NaN           NaN               1.0
# 27         1.0         0.0           NaN           NaN               1.0
# 28         0.0         1.0           NaN           NaN               0.0
# 29         4.0         1.0           NaN           NaN               4.0
# 30         1.0         1.0           NaN           NaN               1.0
#
#     away_score_total  ...                                   penalties_missed  \
# 0                0.0  ...                                                NaN
# 1                2.0  ...                                                NaN
# 2                0.0  ...                                                NaN
# 3                0.0  ...                                                NaN
# 4                0.0  ...                                                NaN
# 5                2.0  ...                                                NaN
# 6                1.0  ...                                                NaN
# 7                0.0  ...                                                NaN
# 8                0.0  ...                                                NaN
# 9                0.0  ...                                                NaN
# 10               1.0  ...                                                NaN
# 11               2.0  ...                                                NaN
# 12               1.0  ...                                                NaN
# 13               0.0  ...                                                NaN
# 14               0.0  ...                                                NaN
# 15               3.0  ...                                                NaN
# 16               2.0  ...                                                NaN
# 17               0.0  ...                                                NaN
# 18               1.0  ...                                                NaN
# 19               2.0  ...                                                NaN
# 20               3.0  ...                                                NaN
# 21               1.0  ...                                                NaN
# 22               2.0  ...                                                NaN
# 23               1.0  ...                                                NaN
# 24               1.0  ...                                                NaN
# 25               3.0  ...                                                NaN
# 26               1.0  ...                                                NaN
# 27               0.0  ...                                                NaN
# 28               1.0  ...                                                NaN
# 29               1.0  ...                                                NaN
# 30               1.0  ...  [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
#
#                                             penalties  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 3   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                             red_cards  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'phase': 'SECOND_HALF', 'time': {'minute': 8...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  [{'phase': 'FIRST_HALF', 'time': {'minute': 44...
#
#                                         game_referees stadium_city  \
# 0   [{'name': 'David R. Elleray', 'role': 'REFEREE...         Kyiv
# 1   [{'name': 'Ruddy Buquet', 'role': 'ADDITIONAL_...       Warsaw
# 2   [{'name': 'Damir Skomina', 'role': 'FOURTH_OFF...      Donetsk
# 3   [{'name': 'Duarte Gomes', 'role': 'ADDITIONAL_...         Kyiv
# 4   [{'name': 'Kyros Vassaras', 'role': 'REFEREE_O...      Donetsk
# 5   [{'name': 'Stéphane Lannoy', 'role': 'FOURTH_O...       Gdansk
# 6   [{'name': 'Michael Mullarkey', 'role': 'ASSIST...       Warsaw
# 7   [{'name': 'Jorge Sousa', 'role': 'ADDITIONAL_A...         Kyiv
# 8   [{'name': 'Tom Harald Hagen', 'role': 'FOURTH_...      Donetsk
# 9   [{'name': 'Jozef Marko', 'role': 'REFEREE_OBSE...       Poznań
# 10  [{'name': 'Jan-Hendrik Salver', 'role': 'ASSIS...       Gdansk
# 11  [{'name': 'Jozef Kliment', 'role': 'UEFA_DELEG...         Lviv
# 12  [{'name': 'Gianluca Rocchi', 'role': 'ADDITION...      Kharkiv
# 13  [{'name': 'Jonas Eriksson', 'role': 'REFEREE',...       Warsaw
# 14  [{'name': 'Euan Norris', 'role': 'ADDITIONAL_A...      Wroclaw
# 15  [{'name': 'Damir Skomina', 'role': 'REFEREE', ...         Kyiv
# 16  [{'name': 'Vladimir Šajn', 'role': 'REFEREE_OB...      Donetsk
# 17  [{'name': 'Pedro Proença', 'role': 'REFEREE', ...       Gdansk
# 18  [{'name': 'Mark Clattenburg', 'role': 'ADDITIO...       Poznań
# 19  [{'name': 'Tom Harald Hagen', 'role': 'FOURTH_...      Kharkiv
# 20  [{'name': 'Viktor Shvetsov', 'role': 'FOURTH_O...         Lviv
# 21  [{'name': 'Florian Meyer', 'role': 'ADDITIONAL...       Warsaw
# 22  [{'name': 'Stéphane Lannoy', 'role': 'REFEREE'...      Wroclaw
# 23  [{'name': 'Bahattin Duran', 'role': 'ASSISTANT...         Kyiv
# 24  [{'name': 'Renato Faverani', 'role': 'ASSISTAN...      Donetsk
# 25  [{'name': 'Sander van Roekel', 'role': 'ASSIST...       Poznań
# 26  [{'name': 'Viktor Kassai', 'role': 'REFEREE', ...       Gdansk
# 27  [{'name': 'Ruddy Buquet', 'role': 'ADDITIONAL_...         Lviv
# 28  [{'name': 'Matej Žunič', 'role': 'ASSISTANT_RE...      Kharkiv
# 29  [{'name': 'Howard Webb', 'role': 'REFEREE', 'n...      Wroclaw
# 30  [{'name': 'David Fernández Borbalán', 'role': ...       Warsaw
#
#                     stadium_name     stadium_name_media  \
# 0                NSC Olimpiyskiy        NSC Olimpiyskiy
# 1               Stadion Narodowy           PGE Narodowy
# 2                  Donbass Arena          Donbass Arena
# 3                NSC Olimpiyskiy        NSC Olimpiyskiy
# 4                  Donbass Arena          Donbass Arena
# 5                 Gdansk Stadium  Stadion Energa Gdansk
# 6               Stadion Narodowy           PGE Narodowy
# 7                NSC Olimpiyskiy        NSC Olimpiyskiy
# 8                  Donbass Arena          Donbass Arena
# 9                 Poznań Stadium         Stadion Poznań
# 10                Gdansk Stadium  Stadion Energa Gdansk
# 11                    Arena Lviv             Arena Lviv
# 12                  OSC Metalist   OSC Metalist Stadion
# 13              Stadion Narodowy           PGE Narodowy
# 14  Stadion Miejski we Wrocławiu        Stadion Miejski
# 15               NSC Olimpiyskiy        NSC Olimpiyskiy
# 16                 Donbass Arena          Donbass Arena
# 17                Gdansk Stadium  Stadion Energa Gdansk
# 18                Poznań Stadium         Stadion Poznań
# 19                  OSC Metalist   OSC Metalist Stadion
# 20                    Arena Lviv             Arena Lviv
# 21              Stadion Narodowy           PGE Narodowy
# 22  Stadion Miejski we Wrocławiu        Stadion Miejski
# 23               NSC Olimpiyskiy        NSC Olimpiyskiy
# 24                 Donbass Arena          Donbass Arena
# 25                Poznań Stadium         Stadion Poznań
# 26                Gdansk Stadium  Stadion Energa Gdansk
# 27                    Arena Lviv             Arena Lviv
# 28                  OSC Metalist   OSC Metalist Stadion
# 29  Stadion Miejski we Wrocławiu        Stadion Miejski
# 30              Stadion Narodowy           PGE Narodowy
#
#            stadium_name_official            stadium_name_event  \
# 0                NSC Olimpiyskiy               NSC Olimpiyskiy
# 1               Stadion Narodowy              Stadion Narodowy
# 2                  Donbass Arena                  Donbas Arena
# 3                NSC Olimpiyskiy               NSC Olimpiyskiy
# 4                  Donbass Arena                  Donbas Arena
# 5                 Gdansk Stadium                Gdansk Stadium
# 6               Stadion Narodowy              Stadion Narodowy
# 7                NSC Olimpiyskiy               NSC Olimpiyskiy
# 8                  Donbass Arena                  Donbas Arena
# 9                 Poznań Stadium                Stadion Poznań
# 10                Gdansk Stadium                Gdansk Stadium
# 11                    Arena Lviv                    Arena Lviv
# 12                  OSC Metalist                  OSC Metalist
# 13              Stadion Narodowy              Stadion Narodowy
# 14  Stadion Miejski we Wrocławiu  Stadion Miejski we Wrocławiu
# 15               NSC Olimpiyskiy               NSC Olimpiyskiy
# 16                 Donbass Arena                  Donbas Arena
# 17                Gdansk Stadium                Gdansk Stadium
# 18                Poznań Stadium                Stadion Poznań
# 19                  OSC Metalist                  OSC Metalist
# 20                    Arena Lviv                    Arena Lviv
# 21              Stadion Narodowy              Stadion Narodowy
# 22  Stadion Miejski we Wrocławiu  Stadion Miejski we Wrocławiu
# 23               NSC Olimpiyskiy               NSC Olimpiyskiy
# 24                 Donbass Arena                  Donbas Arena
# 25                Poznań Stadium                Stadion Poznań
# 26                Gdansk Stadium                Gdansk Stadium
# 27                    Arena Lviv                    Arena Lviv
# 28                  OSC Metalist                  OSC Metalist
# 29  Stadion Miejski we Wrocławiu  Stadion Miejski we Wrocławiu
# 30              Stadion Narodowy              Stadion Narodowy
#
#         stadium_name_sponsor
# 0            NSC Olimpiyskiy
# 1               PGE Narodowy
# 2              Donbass Arena
# 3            NSC Olimpiyskiy
# 4              Donbass Arena
# 5      STADION ENERGA GDANSK
# 6               PGE Narodowy
# 7            NSC Olimpiyskiy
# 8              Donbass Arena
# 9             Poznań Stadium
# 10     STADION ENERGA GDANSK
# 11                Arena Lviv
# 12              OSC Metalist
# 13              PGE Narodowy
# 14  Tarczynski Arena Wroclaw
# 15           NSC Olimpiyskiy
# 16             Donbass Arena
# 17     STADION ENERGA GDANSK
# 18            Poznań Stadium
# 19              OSC Metalist
# 20                Arena Lviv
# 21              PGE Narodowy
# 22  Tarczynski Arena Wroclaw
# 23           NSC Olimpiyskiy
# 24             Donbass Arena
# 25            Poznań Stadium
# 26     STADION ENERGA GDANSK
# 27                Arena Lviv
# 28              OSC Metalist
# 29  Tarczynski Arena Wroclaw
# 30              PGE Narodowy
#
# [31 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   home_team              31 non-null     object
#  1   away_team              31 non-null     object
#  2   home_team_code         31 non-null     object
#  3   away_team_code         31 non-null     object
#  4   home_score             31 non-null     float64
#  5   away_score             31 non-null     float64
#  6   home_penalty           2 non-null      float64
#  7   away_penalty           2 non-null      float64
#  8   home_score_total       31 non-null     float64
#  9   away_score_total       31 non-null     float64
#  10  winner                 26 non-null     object
#  11  winner_reason          31 non-null     object
#  12  year                   31 non-null     int64
#  13  date                   31 non-null     object
#  14  date_time              31 non-null     object
#  15  utc_offset_hours       31 non-null     float64
#  16  group_name             24 non-null     object
#  17  matchday_name          31 non-null     object
#  18  condition_humidity     30 non-null     float64
#  19  condition_pitch        29 non-null     object
#  20  condition_temperature  30 non-null     float64
#  21  condition_weather      30 non-null     object
#  22  condition_wind_speed   30 non-null     float64
#  23  status                 31 non-null     object
#  24  type                   31 non-null     object
#  25  round                  31 non-null     object
#  26  round_mode             31 non-null     object
#  27  match_attendance       31 non-null     float64
#  28  stadium_id             31 non-null     int64
#  29  stadium_country_code   31 non-null     object
#  30  stadium_capacity       31 non-null     float64
#  31  stadium_latitude       31 non-null     float64
#  32  stadium_longitude      31 non-null     float64
#  33  stadium_pitch_length   31 non-null     float64
#  34  stadium_pitch_width    31 non-null     float64
#  35  goals                  29 non-null     object
#  36  penalties_missed       1 non-null      object
#  37  penalties              2 non-null      object
#  38  red_cards              2 non-null      object
#  39  game_referees          31 non-null     object
#  40  stadium_city           31 non-null     object
#  41  stadium_name           31 non-null     object
#  42  stadium_name_media     31 non-null     object
#  43  stadium_name_official  31 non-null     object
#  44  stadium_name_event     31 non-null     object
#  45  stadium_name_sponsor   31 non-null     object
# dtypes: float64(16), int64(2), object(28)
# memory usage: 11.3+ KB

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# home_team                 0
# away_team                 0
# home_team_code            0
# away_team_code            0
# home_score                0
# away_score                0
# home_penalty             29
# away_penalty             29
# home_score_total          0
# away_score_total          0
# winner                    5
# winner_reason             0
# year                      0
# date                      0
# date_time                 0
# utc_offset_hours          0
# group_name                7
# matchday_name             0
# condition_humidity        1
# condition_pitch           2
# condition_temperature     1
# condition_weather         1
# condition_wind_speed      1
# status                    0
# type                      0
# round                     0
# round_mode                0
# match_attendance          0
# stadium_id                0
# stadium_country_code      0
# stadium_capacity          0
# stadium_latitude          0
# stadium_longitude         0
# stadium_pitch_length      0
# stadium_pitch_width       0
# goals                     2
# penalties_missed         30
# penalties                29
# red_cards                29
# game_referees             0
# stadium_city              0
# stadium_name              0
# stadium_name_media        0
# stadium_name_official     0
# stadium_name_event        0
# stadium_name_sponsor      0
# dtype: int64

# %%
df.describe()
# Out:
#        home_score  away_score  home_penalty  away_penalty  home_score_total  \
# count   31.000000   31.000000           2.0           2.0         31.000000
# mean     1.419355    1.032258           2.0           4.0          1.419355
# std      1.204829    0.982645           0.0           0.0          1.204829
# min      0.000000    0.000000           2.0           4.0          0.000000
# 25%      1.000000    0.000000           2.0           4.0          1.000000
# 50%      1.000000    1.000000           2.0           4.0          1.000000
# 75%      2.000000    2.000000           2.0           4.0          2.000000
# max      4.000000    3.000000           2.0           4.0          4.000000
#
#        away_score_total    year  utc_offset_hours  condition_humidity  \
# count         31.000000    31.0         31.000000           30.000000
# mean           1.032258  2012.0          2.516129           58.866667
# std            0.982645     0.0          0.508001           13.474710
# min            0.000000  2012.0          2.000000           29.000000
# 25%            0.000000  2012.0          2.000000           49.250000
# 50%            1.000000  2012.0          3.000000           57.500000
# 75%            2.000000  2012.0          3.000000           69.250000
# max            3.000000  2012.0          3.000000           85.000000
#
#        condition_temperature  condition_wind_speed  match_attendance  \
# count              30.000000             30.000000         31.000000
# mean               22.233333              9.833333      46471.387097
# std                 4.651165              4.094431      10513.351488
# min                11.000000              3.000000      31840.000000
# 25%                19.250000              6.250000      38772.500000
# 50%                23.500000              9.500000      41105.000000
# 75%                25.750000             12.750000      55602.000000
# max                30.000000             20.000000      64640.000000
#
#          stadium_id  stadium_capacity  stadium_latitude  stadium_longitude  \
# count  3.100000e+01         31.000000         31.000000          31.000000
# mean   2.016263e+08      49521.032258         50.993172          25.922559
# std    1.003768e+08      11094.254352          1.948926           8.083668
# min    6.353900e+04      34725.000000         47.994706          16.858281
# 25%    2.500004e+08      41524.000000         49.878061          18.640278
# 50%    2.500012e+08      41837.000000         50.433439          24.027778
# 75%    2.500012e+08      58274.000000         52.239406          33.391799
# max    2.500014e+08      68000.000000         54.390000          37.785789
#
#        stadium_pitch_length  stadium_pitch_width
# count                  31.0                 31.0
# mean                  105.0                 68.0
# std                     0.0                  0.0
# min                   105.0                 68.0
# 25%                   105.0                 68.0
# 50%                   105.0                 68.0
# 75%                   105.0                 68.0
# max                   105.0                 68.0

# %%
import pandas as pd
# View all columns of the dataframe
pd.set_option('display.max_columns', None)
df
# Out:
#               home_team            away_team home_team_code away_team_code  \
# 0                 Spain                Italy            ESP            ITA
# 1               Germany                Italy            GER            ITA
# 2              Portugal                Spain            POR            ESP
# 3               England                Italy            ENG            ITA
# 4                 Spain               France            ESP            FRA
# 5               Germany               Greece            GER            GRE
# 6               Czechia             Portugal            CZE            POR
# 7                Sweden               France            SWE            FRA
# 8               England              Ukraine            ENG            UKR
# 9                 Italy  Republic of Ireland            ITA            IRL
# 10              Croatia                Spain            CRO            ESP
# 11              Denmark              Germany            DEN            GER
# 12             Portugal          Netherlands            POR            NED
# 13               Greece               Russia            GRE            RUS
# 14              Czechia               Poland            CZE            POL
# 15               Sweden              England            SWE            ENG
# 16              Ukraine               France            UKR            FRA
# 17                Spain  Republic of Ireland            ESP            IRL
# 18                Italy              Croatia            ITA            CRO
# 19          Netherlands              Germany            NED            GER
# 20              Denmark             Portugal            DEN            POR
# 21               Poland               Russia            POL            RUS
# 22               Greece              Czechia            GRE            CZE
# 23              Ukraine               Sweden            UKR            SWE
# 24               France              England            FRA            ENG
# 25  Republic of Ireland              Croatia            IRL            CRO
# 26                Spain                Italy            ESP            ITA
# 27              Germany             Portugal            GER            POR
# 28          Netherlands              Denmark            NED            DEN
# 29               Russia              Czechia            RUS            CZE
# 30               Poland               Greece            POL            GRE
#
#     home_score  away_score  home_penalty  away_penalty  home_score_total  \
# 0          4.0         0.0           NaN           NaN               4.0
# 1          1.0         2.0           NaN           NaN               1.0
# 2          0.0         0.0           2.0           4.0               0.0
# 3          0.0         0.0           2.0           4.0               0.0
# 4          2.0         0.0           NaN           NaN               2.0
# 5          4.0         2.0           NaN           NaN               4.0
# 6          0.0         1.0           NaN           NaN               0.0
# 7          2.0         0.0           NaN           NaN               2.0
# 8          1.0         0.0           NaN           NaN               1.0
# 9          2.0         0.0           NaN           NaN               2.0
# 10         0.0         1.0           NaN           NaN               0.0
# 11         1.0         2.0           NaN           NaN               1.0
# 12         2.0         1.0           NaN           NaN               2.0
# 13         1.0         0.0           NaN           NaN               1.0
# 14         1.0         0.0           NaN           NaN               1.0
# 15         2.0         3.0           NaN           NaN               2.0
# 16         0.0         2.0           NaN           NaN               0.0
# 17         4.0         0.0           NaN           NaN               4.0
# 18         1.0         1.0           NaN           NaN               1.0
# 19         1.0         2.0           NaN           NaN               1.0
# 20         2.0         3.0           NaN           NaN               2.0
# 21         1.0         1.0           NaN           NaN               1.0
# 22         1.0         2.0           NaN           NaN               1.0
# 23         2.0         1.0           NaN           NaN               2.0
# 24         1.0         1.0           NaN           NaN               1.0
# 25         1.0         3.0           NaN           NaN               1.0
# 26         1.0         1.0           NaN           NaN               1.0
# 27         1.0         0.0           NaN           NaN               1.0
# 28         0.0         1.0           NaN           NaN               0.0
# 29         4.0         1.0           NaN           NaN               4.0
# 30         1.0         1.0           NaN           NaN               1.0
#
#     away_score_total    winner     winner_reason  year        date  \
# 0                0.0     Spain       WIN_REGULAR  2012  2012-07-01
# 1                2.0     Italy       WIN_REGULAR  2012  2012-06-28
# 2                0.0     Spain  WIN_ON_PENALTIES  2012  2012-06-27
# 3                0.0     Italy  WIN_ON_PENALTIES  2012  2012-06-24
# 4                0.0     Spain       WIN_REGULAR  2012  2012-06-23
# 5                2.0   Germany       WIN_REGULAR  2012  2012-06-22
# 6                1.0  Portugal       WIN_REGULAR  2012  2012-06-21
# 7                0.0    Sweden       WIN_REGULAR  2012  2012-06-19
# 8                0.0   England       WIN_REGULAR  2012  2012-06-19
# 9                0.0     Italy       WIN_REGULAR  2012  2012-06-18
# 10               1.0     Spain       WIN_REGULAR  2012  2012-06-18
# 11               2.0   Germany       WIN_REGULAR  2012  2012-06-17
# 12               1.0  Portugal       WIN_REGULAR  2012  2012-06-17
# 13               0.0    Greece       WIN_REGULAR  2012  2012-06-16
# 14               0.0   Czechia       WIN_REGULAR  2012  2012-06-16
# 15               3.0   England       WIN_REGULAR  2012  2012-06-15
# 16               2.0    France       WIN_REGULAR  2012  2012-06-15
# 17               0.0     Spain       WIN_REGULAR  2012  2012-06-14
# 18               1.0       NaN              DRAW  2012  2012-06-14
# 19               2.0   Germany       WIN_REGULAR  2012  2012-06-13
# 20               3.0  Portugal       WIN_REGULAR  2012  2012-06-13
# 21               1.0       NaN              DRAW  2012  2012-06-12
# 22               2.0   Czechia       WIN_REGULAR  2012  2012-06-12
# 23               1.0   Ukraine       WIN_REGULAR  2012  2012-06-11
# 24               1.0       NaN              DRAW  2012  2012-06-11
# 25               3.0   Croatia       WIN_REGULAR  2012  2012-06-10
# 26               1.0       NaN              DRAW  2012  2012-06-10
# 27               0.0   Germany       WIN_REGULAR  2012  2012-06-09
# 28               1.0   Denmark       WIN_REGULAR  2012  2012-06-09
# 29               1.0    Russia       WIN_REGULAR  2012  2012-06-08
# 30               1.0       NaN              DRAW  2012  2012-06-08
#
#                date_time  utc_offset_hours group_name matchday_name  \
# 0   2012-07-01T18:45:00Z               3.0        NaN           MD6
# 1   2012-06-28T18:45:00Z               2.0        NaN           MD5
# 2   2012-06-27T18:45:00Z               3.0        NaN           MD5
# 3   2012-06-24T18:45:00Z               3.0        NaN           MD4
# 4   2012-06-23T18:45:00Z               3.0        NaN           MD4
# 5   2012-06-22T18:45:00Z               2.0        NaN           MD4
# 6   2012-06-21T18:45:00Z               2.0        NaN           MD4
# 7   2012-06-19T18:45:00Z               3.0    Group D           MD3
# 8   2012-06-19T18:45:00Z               3.0    Group D           MD3
# 9   2012-06-18T18:45:00Z               2.0    Group C           MD3
# 10  2012-06-18T18:45:00Z               2.0    Group C           MD3
# 11  2012-06-17T18:45:00Z               3.0    Group B           MD3
# 12  2012-06-17T18:45:00Z               3.0    Group B           MD3
# 13  2012-06-16T18:45:00Z               2.0    Group A           MD3
# 14  2012-06-16T18:45:00Z               2.0    Group A           MD3
# 15  2012-06-15T18:45:00Z               3.0    Group D           MD2
# 16  2012-06-15T16:00:00Z               3.0    Group D           MD2
# 17  2012-06-14T18:45:00Z               2.0    Group C           MD2
# 18  2012-06-14T16:00:00Z               2.0    Group C           MD2
# 19  2012-06-13T18:45:00Z               3.0    Group B           MD2
# 20  2012-06-13T16:00:00Z               3.0    Group B           MD2
# 21  2012-06-12T18:45:00Z               2.0    Group A           MD2
# 22  2012-06-12T16:00:00Z               2.0    Group A           MD2
# 23  2012-06-11T18:45:00Z               3.0    Group D           MD1
# 24  2012-06-11T16:00:00Z               3.0    Group D           MD1
# 25  2012-06-10T18:45:00Z               2.0    Group C           MD1
# 26  2012-06-10T16:00:00Z               2.0    Group C           MD1
# 27  2012-06-09T18:45:00Z               3.0    Group B           MD1
# 28  2012-06-09T16:00:00Z               3.0    Group B           MD1
# 29  2012-06-08T18:45:00Z               2.0    Group A           MD1
# 30  2012-06-08T16:00:00Z               2.0    Group A           MD1
#
#     condition_humidity condition_pitch  condition_temperature  \
# 0                 42.0             DRY                   26.0
# 1                 49.0             DRY                   20.0
# 2                  NaN             NaN                    NaN
# 3                 41.0             DRY                   24.0
# 4                 47.0             DRY                   24.0
# 5                 70.0             WET                   17.0
# 6                 72.0             DRY                   23.0
# 7                 52.0             DRY                   26.0
# 8                 44.0             DRY                   23.0
# 9                 52.0            SOFT                   28.0
# 10                57.0             NaN                   24.0
# 11                58.0             DRY                   26.0
# 12                48.0             DRY                   24.0
# 13                42.0             DRY                   25.0
# 14                65.0            SOFT                   24.0
# 15                67.0             DRY                   19.0
# 16                65.0            SOFT                   27.0
# 17                64.0             WET                   11.0
# 18                72.0             WET                   14.0
# 19                61.0             DRY                   29.0
# 20                55.0             DRY                   19.0
# 21                56.0             DRY                   21.0
# 22                75.0            SOFT                   20.0
# 23                51.0             DRY                   25.0
# 24                29.0             DRY                   30.0
# 25                77.0             WET                   16.0
# 26                50.0            SOFT                   18.0
# 27                78.0             WET                   22.0
# 28                65.0             DRY                   27.0
# 29                85.0             WET                   15.0
# 30                77.0             DRY                   20.0
#
#       condition_weather  condition_wind_speed    status         type  \
# 0           CLEAR_NIGHT                   8.0  FINISHED       SINGLE
# 1   PARTLY_CLOUDY_NIGHT                  12.0  FINISHED       SINGLE
# 2                   NaN                   NaN  FINISHED       SINGLE
# 3           CLEAR_NIGHT                   7.0  FINISHED       SINGLE
# 4   PARTLY_CLOUDY_NIGHT                   9.0  FINISHED       SINGLE
# 5                CLOUDY                   9.0  FINISHED       SINGLE
# 6         PARTLY_CLOUDY                  10.0  FINISHED       SINGLE
# 7           CLEAR_NIGHT                  10.0  FINISHED  GROUP_STAGE
# 8           CLEAR_NIGHT                  10.0  FINISHED  GROUP_STAGE
# 9           CLEAR_NIGHT                  13.0  FINISHED  GROUP_STAGE
# 10                SUNNY                  16.0  FINISHED  GROUP_STAGE
# 11          CLEAR_NIGHT                   6.0  FINISHED  GROUP_STAGE
# 12          CLEAR_NIGHT                   8.0  FINISHED  GROUP_STAGE
# 13  PARTLY_CLOUDY_NIGHT                  12.0  FINISHED  GROUP_STAGE
# 14         CLOUDY_NIGHT                  15.0  FINISHED  GROUP_STAGE
# 15         CLOUDY_NIGHT                  10.0  FINISHED  GROUP_STAGE
# 16                 RAIN                   4.0  FINISHED  GROUP_STAGE
# 17                 RAIN                  12.0  FINISHED  GROUP_STAGE
# 18               CLOUDY                  14.0  FINISHED  GROUP_STAGE
# 19          CLEAR_NIGHT                   9.0  FINISHED  GROUP_STAGE
# 20        PARTLY_CLOUDY                  20.0  FINISHED  GROUP_STAGE
# 21        PARTLY_CLOUDY                  14.0  FINISHED  GROUP_STAGE
# 22               CLOUDY                   5.0  FINISHED  GROUP_STAGE
# 23          CLEAR_NIGHT                   6.0  FINISHED  GROUP_STAGE
# 24                SUNNY                  14.0  FINISHED  GROUP_STAGE
# 25                 RAIN                   3.0  FINISHED  GROUP_STAGE
# 26        PARTLY_CLOUDY                   8.0  FINISHED  GROUP_STAGE
# 27         CLOUDY_NIGHT                   5.0  FINISHED  GROUP_STAGE
# 28        PARTLY_CLOUDY                   6.0  FINISHED  GROUP_STAGE
# 29                 RAIN                  15.0  FINISHED  GROUP_STAGE
# 30        PARTLY_CLOUDY                   5.0  FINISHED  GROUP_STAGE
#
#               round round_mode  match_attendance  stadium_id  \
# 0             FINAL      FINAL           63170.0   250001449
# 1         SEMIFINAL  KNOCK_OUT           55540.0   250001178
# 2         SEMIFINAL  KNOCK_OUT           48000.0   250000431
# 3    QUARTER_FINALS  KNOCK_OUT           64340.0   250001449
# 4    QUARTER_FINALS  KNOCK_OUT           47000.0   250000431
# 5    QUARTER_FINALS  KNOCK_OUT           38751.0   250001177
# 6    QUARTER_FINALS  KNOCK_OUT           55590.0   250001178
# 7   GROUP_STANDINGS      GROUP           63010.0   250001449
# 8   GROUP_STANDINGS      GROUP           48700.0   250000431
# 9   GROUP_STANDINGS      GROUP           38794.0       63539
# 10  GROUP_STANDINGS      GROUP           39076.0   250001177
# 11  GROUP_STANDINGS      GROUP           32990.0   250001180
# 12  GROUP_STANDINGS      GROUP           37445.0       66282
# 13  GROUP_STANDINGS      GROUP           55614.0   250001178
# 14  GROUP_STANDINGS      GROUP           41000.0   250001179
# 15  GROUP_STANDINGS      GROUP           64640.0   250001449
# 16  GROUP_STANDINGS      GROUP           48000.0   250000431
# 17  GROUP_STANDINGS      GROUP           39150.0   250001177
# 18  GROUP_STANDINGS      GROUP           37096.0       63539
# 19  GROUP_STANDINGS      GROUP           37750.0       66282
# 20  GROUP_STANDINGS      GROUP           31840.0   250001180
# 21  GROUP_STANDINGS      GROUP           55920.0   250001178
# 22  GROUP_STANDINGS      GROUP           41105.0   250001179
# 23  GROUP_STANDINGS      GROUP           64290.0   250001449
# 24  GROUP_STANDINGS      GROUP           47400.0   250000431
# 25  GROUP_STANDINGS      GROUP           39550.0       63539
# 26  GROUP_STANDINGS      GROUP           38869.0   250001177
# 27  GROUP_STANDINGS      GROUP           32990.0   250001180
# 28  GROUP_STANDINGS      GROUP           35923.0       66282
# 29  GROUP_STANDINGS      GROUP           41000.0   250001179
# 30  GROUP_STANDINGS      GROUP           56070.0   250001178
#
#    stadium_country_code  stadium_capacity  stadium_latitude  \
# 0                   UKR           68000.0         50.433439
# 1                   POL           58274.0         52.239406
# 2                   UKR           52667.0         47.994706
# 3                   UKR           68000.0         50.433439
# 4                   UKR           52667.0         47.994706
# 5                   POL           41524.0         54.390000
# 6                   POL           58274.0         52.239406
# 7                   UKR           68000.0         50.433439
# 8                   UKR           52667.0         47.994706
# 9                   POL           41609.0         52.397686
# 10                  POL           41524.0         54.390000
# 11                  UKR           34725.0         49.775278
# 12                  UKR           39946.0         49.980844
# 13                  POL           58274.0         52.239406
# 14                  POL           41837.0         51.143056
# 15                  UKR           68000.0         50.433439
# 16                  UKR           52667.0         47.994706
# 17                  POL           41524.0         54.390000
# 18                  POL           41609.0         52.397686
# 19                  UKR           39946.0         49.980844
# 20                  UKR           34725.0         49.775278
# 21                  POL           58274.0         52.239406
# 22                  POL           41837.0         51.143056
# 23                  UKR           68000.0         50.433439
# 24                  UKR           52667.0         47.994706
# 25                  POL           41609.0         52.397686
# 26                  POL           41524.0         54.390000
# 27                  UKR           34725.0         49.775278
# 28                  UKR           39946.0         49.980844
# 29                  POL           41837.0         51.143056
# 30                  POL           58274.0         52.239406
#
#     stadium_longitude  stadium_pitch_length  stadium_pitch_width  \
# 0           30.522114                 105.0                 68.0
# 1           21.045881                 105.0                 68.0
# 2           37.785789                 105.0                 68.0
# 3           30.522114                 105.0                 68.0
# 4           37.785789                 105.0                 68.0
# 5           18.640278                 105.0                 68.0
# 6           21.045881                 105.0                 68.0
# 7           30.522114                 105.0                 68.0
# 8           37.785789                 105.0                 68.0
# 9           16.858281                 105.0                 68.0
# 10          18.640278                 105.0                 68.0
# 11          24.027778                 105.0                 68.0
# 12          36.261483                 105.0                 68.0
# 13          21.045881                 105.0                 68.0
# 14          16.942222                 105.0                 68.0
# 15          30.522114                 105.0                 68.0
# 16          37.785789                 105.0                 68.0
# 17          18.640278                 105.0                 68.0
# 18          16.858281                 105.0                 68.0
# 19          36.261483                 105.0                 68.0
# 20          24.027778                 105.0                 68.0
# 21          21.045881                 105.0                 68.0
# 22          16.942222                 105.0                 68.0
# 23          30.522114                 105.0                 68.0
# 24          37.785789                 105.0                 68.0
# 25          16.858281                 105.0                 68.0
# 26          18.640278                 105.0                 68.0
# 27          24.027778                 105.0                 68.0
# 28          36.261483                 105.0                 68.0
# 29          16.942222                 105.0                 68.0
# 30          21.045881                 105.0                 68.0
#
#                                                 goals  \
# 0   [{'phase': 'FIRST_HALF', 'time': {'minute': 14...
# 1   [{'phase': 'FIRST_HALF', 'time': {'minute': 20...
# 2                                                 NaN
# 3                                                 NaN
# 4   [{'phase': 'FIRST_HALF', 'time': {'minute': 19...
# 5   [{'phase': 'FIRST_HALF', 'time': {'minute': 39...
# 6   [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
# 7   [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 8   [{'phase': 'SECOND_HALF', 'time': {'minute': 4...
# 9   [{'phase': 'FIRST_HALF', 'time': {'minute': 35...
# 10  [{'phase': 'SECOND_HALF', 'time': {'minute': 8...
# 11  [{'phase': 'FIRST_HALF', 'time': {'minute': 19...
# 12  [{'phase': 'FIRST_HALF', 'time': {'minute': 11...
# 13  [{'phase': 'FIRST_HALF', 'time': {'injuryMinut...
# 14  [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
# 15  [{'phase': 'FIRST_HALF', 'time': {'minute': 23...
# 16  [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 17  [{'phase': 'FIRST_HALF', 'time': {'minute': 4,...
# 18  [{'phase': 'FIRST_HALF', 'time': {'minute': 39...
# 19  [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 20  [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 21  [{'phase': 'FIRST_HALF', 'time': {'minute': 37...
# 22  [{'phase': 'FIRST_HALF', 'time': {'minute': 3,...
# 23  [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 24  [{'phase': 'FIRST_HALF', 'time': {'minute': 30...
# 25  [{'phase': 'FIRST_HALF', 'time': {'minute': 3,...
# 26  [{'phase': 'SECOND_HALF', 'time': {'minute': 6...
# 27  [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
# 28  [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 29  [{'phase': 'FIRST_HALF', 'time': {'minute': 15...
# 30  [{'phase': 'FIRST_HALF', 'time': {'minute': 17...
#
#                                      penalties_missed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
#
#                                             penalties  \
# 0                                                 NaN
# 1                                                 NaN
# 2   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 3   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                             red_cards  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'phase': 'SECOND_HALF', 'time': {'minute': 8...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30  [{'phase': 'FIRST_HALF', 'time': {'minute': 44...
#
#                                         game_referees stadium_city  \
# 0   [{'name': 'David R. Elleray', 'role': 'REFEREE...         Kyiv
# 1   [{'name': 'Ruddy Buquet', 'role': 'ADDITIONAL_...       Warsaw
# 2   [{'name': 'Damir Skomina', 'role': 'FOURTH_OFF...      Donetsk
# 3   [{'name': 'Duarte Gomes', 'role': 'ADDITIONAL_...         Kyiv
# 4   [{'name': 'Kyros Vassaras', 'role': 'REFEREE_O...      Donetsk
# 5   [{'name': 'Stéphane Lannoy', 'role': 'FOURTH_O...       Gdansk
# 6   [{'name': 'Michael Mullarkey', 'role': 'ASSIST...       Warsaw
# 7   [{'name': 'Jorge Sousa', 'role': 'ADDITIONAL_A...         Kyiv
# 8   [{'name': 'Tom Harald Hagen', 'role': 'FOURTH_...      Donetsk
# 9   [{'name': 'Jozef Marko', 'role': 'REFEREE_OBSE...       Poznań
# 10  [{'name': 'Jan-Hendrik Salver', 'role': 'ASSIS...       Gdansk
# 11  [{'name': 'Jozef Kliment', 'role': 'UEFA_DELEG...         Lviv
# 12  [{'name': 'Gianluca Rocchi', 'role': 'ADDITION...      Kharkiv
# 13  [{'name': 'Jonas Eriksson', 'role': 'REFEREE',...       Warsaw
# 14  [{'name': 'Euan Norris', 'role': 'ADDITIONAL_A...      Wroclaw
# 15  [{'name': 'Damir Skomina', 'role': 'REFEREE', ...         Kyiv
# 16  [{'name': 'Vladimir Šajn', 'role': 'REFEREE_OB...      Donetsk
# 17  [{'name': 'Pedro Proença', 'role': 'REFEREE', ...       Gdansk
# 18  [{'name': 'Mark Clattenburg', 'role': 'ADDITIO...       Poznań
# 19  [{'name': 'Tom Harald Hagen', 'role': 'FOURTH_...      Kharkiv
# 20  [{'name': 'Viktor Shvetsov', 'role': 'FOURTH_O...         Lviv
# 21  [{'name': 'Florian Meyer', 'role': 'ADDITIONAL...       Warsaw
# 22  [{'name': 'Stéphane Lannoy', 'role': 'REFEREE'...      Wroclaw
# 23  [{'name': 'Bahattin Duran', 'role': 'ASSISTANT...         Kyiv
# 24  [{'name': 'Renato Faverani', 'role': 'ASSISTAN...      Donetsk
# 25  [{'name': 'Sander van Roekel', 'role': 'ASSIST...       Poznań
# 26  [{'name': 'Viktor Kassai', 'role': 'REFEREE', ...       Gdansk
# 27  [{'name': 'Ruddy Buquet', 'role': 'ADDITIONAL_...         Lviv
# 28  [{'name': 'Matej Žunič', 'role': 'ASSISTANT_RE...      Kharkiv
# 29  [{'name': 'Howard Webb', 'role': 'REFEREE', 'n...      Wroclaw
# 30  [{'name': 'David Fernández Borbalán', 'role': ...       Warsaw
#
#                     stadium_name     stadium_name_media  \
# 0                NSC Olimpiyskiy        NSC Olimpiyskiy
# 1               Stadion Narodowy           PGE Narodowy
# 2                  Donbass Arena          Donbass Arena
# 3                NSC Olimpiyskiy        NSC Olimpiyskiy
# 4                  Donbass Arena          Donbass Arena
# 5                 Gdansk Stadium  Stadion Energa Gdansk
# 6               Stadion Narodowy           PGE Narodowy
# 7                NSC Olimpiyskiy        NSC Olimpiyskiy
# 8                  Donbass Arena          Donbass Arena
# 9                 Poznań Stadium         Stadion Poznań
# 10                Gdansk Stadium  Stadion Energa Gdansk
# 11                    Arena Lviv             Arena Lviv
# 12                  OSC Metalist   OSC Metalist Stadion
# 13              Stadion Narodowy           PGE Narodowy
# 14  Stadion Miejski we Wrocławiu        Stadion Miejski
# 15               NSC Olimpiyskiy        NSC Olimpiyskiy
# 16                 Donbass Arena          Donbass Arena
# 17                Gdansk Stadium  Stadion Energa Gdansk
# 18                Poznań Stadium         Stadion Poznań
# 19                  OSC Metalist   OSC Metalist Stadion
# 20                    Arena Lviv             Arena Lviv
# 21              Stadion Narodowy           PGE Narodowy
# 22  Stadion Miejski we Wrocławiu        Stadion Miejski
# 23               NSC Olimpiyskiy        NSC Olimpiyskiy
# 24                 Donbass Arena          Donbass Arena
# 25                Poznań Stadium         Stadion Poznań
# 26                Gdansk Stadium  Stadion Energa Gdansk
# 27                    Arena Lviv             Arena Lviv
# 28                  OSC Metalist   OSC Metalist Stadion
# 29  Stadion Miejski we Wrocławiu        Stadion Miejski
# 30              Stadion Narodowy           PGE Narodowy
#
#            stadium_name_official            stadium_name_event  \
# 0                NSC Olimpiyskiy               NSC Olimpiyskiy
# 1               Stadion Narodowy              Stadion Narodowy
# 2                  Donbass Arena                  Donbas Arena
# 3                NSC Olimpiyskiy               NSC Olimpiyskiy
# 4                  Donbass Arena                  Donbas Arena
# 5                 Gdansk Stadium                Gdansk Stadium
# 6               Stadion Narodowy              Stadion Narodowy
# 7                NSC Olimpiyskiy               NSC Olimpiyskiy
# 8                  Donbass Arena                  Donbas Arena
# 9                 Poznań Stadium                Stadion Poznań
# 10                Gdansk Stadium                Gdansk Stadium
# 11                    Arena Lviv                    Arena Lviv
# 12                  OSC Metalist                  OSC Metalist
# 13              Stadion Narodowy              Stadion Narodowy
# 14  Stadion Miejski we Wrocławiu  Stadion Miejski we Wrocławiu
# 15               NSC Olimpiyskiy               NSC Olimpiyskiy
# 16                 Donbass Arena                  Donbas Arena
# 17                Gdansk Stadium                Gdansk Stadium
# 18                Poznań Stadium                Stadion Poznań
# 19                  OSC Metalist                  OSC Metalist
# 20                    Arena Lviv                    Arena Lviv
# 21              Stadion Narodowy              Stadion Narodowy
# 22  Stadion Miejski we Wrocławiu  Stadion Miejski we Wrocławiu
# 23               NSC Olimpiyskiy               NSC Olimpiyskiy
# 24                 Donbass Arena                  Donbas Arena
# 25                Poznań Stadium                Stadion Poznań
# 26                Gdansk Stadium                Gdansk Stadium
# 27                    Arena Lviv                    Arena Lviv
# 28                  OSC Metalist                  OSC Metalist
# 29  Stadion Miejski we Wrocławiu  Stadion Miejski we Wrocławiu
# 30              Stadion Narodowy              Stadion Narodowy
#
#         stadium_name_sponsor
# 0            NSC Olimpiyskiy
# 1               PGE Narodowy
# 2              Donbass Arena
# 3            NSC Olimpiyskiy
# 4              Donbass Arena
# 5      STADION ENERGA GDANSK
# 6               PGE Narodowy
# 7            NSC Olimpiyskiy
# 8              Donbass Arena
# 9             Poznań Stadium
# 10     STADION ENERGA GDANSK
# 11                Arena Lviv
# 12              OSC Metalist
# 13              PGE Narodowy
# 14  Tarczynski Arena Wroclaw
# 15           NSC Olimpiyskiy
# 16             Donbass Arena
# 17     STADION ENERGA GDANSK
# 18            Poznań Stadium
# 19              OSC Metalist
# 20                Arena Lviv
# 21              PGE Narodowy
# 22  Tarczynski Arena Wroclaw
# 23           NSC Olimpiyskiy
# 24             Donbass Arena
# 25            Poznań Stadium
# 26     STADION ENERGA GDANSK
# 27                Arena Lviv
# 28              OSC Metalist
# 29  Tarczynski Arena Wroclaw
# 30              PGE Narodowy

# %% [markdown]
# Missing Values of coundition_pitch column are replaced by the most frequent entry of the column

# %%
condition_pitch_list = df['condition_pitch'].tolist()

# %%
from collections import Counter
import numpy as np
data_array = np.array(condition_pitch_list, dtype=object)
data_array
# Out:
# array(['DRY', 'DRY', nan, 'DRY', 'DRY', 'WET', 'DRY', 'DRY', 'DRY',
#        'SOFT', nan, 'DRY', 'DRY', 'DRY', 'SOFT', 'DRY', 'SOFT', 'WET',
#        'WET', 'DRY', 'DRY', 'DRY', 'SOFT', 'DRY', 'DRY', 'WET', 'SOFT',
#        'WET', 'DRY', 'WET', 'DRY'], dtype=object)

# %%
most_frequent = Counter(data_array[~pd.isna(data_array)]).most_common(1)[0][0]
most_frequent
# Out:
# 'DRY'

# %%
df['condition_pitch'] = df['condition_pitch'].fillna(most_frequent)

# %%
# Check for null values in each column
null_values = df.isnull().sum()

# Print the results
print(null_values)
# Out:
# home_team                 0
# away_team                 0
# home_team_code            0
# away_team_code            0
# home_score                0
# away_score                0
# home_penalty             29
# away_penalty             29
# home_score_total          0
# away_score_total          0
# winner                    5
# winner_reason             0
# year                      0
# date                      0
# date_time                 0
# utc_offset_hours          0
# group_name                7
# matchday_name             0
# condition_humidity        1
# condition_pitch           0
# condition_temperature     1
# condition_weather         1
# condition_wind_speed      1
# status                    0
# type                      0
# round                     0
# round_mode                0
# match_attendance          0
# stadium_id                0
# stadium_country_code      0
# stadium_capacity          0
# stadium_latitude          0
# stadium_longitude         0
# stadium_pitch_length      0
# stadium_pitch_width       0
# goals                     2
# penalties_missed         30
# penalties                29
# red_cards                29
# game_referees             0
# stadium_city              0
# stadium_name              0
# stadium_name_media        0
# stadium_name_official     0
# stadium_name_event        0
# stadium_name_sponsor      0
# dtype: int64

# %%
condition_weather_list = df['condition_weather'].tolist()
condition_weather_list
# Out:
# ['CLEAR_NIGHT',
#  'PARTLY_CLOUDY_NIGHT',
#  nan,
#  'CLEAR_NIGHT',
#  'PARTLY_CLOUDY_NIGHT',
#  'CLOUDY',
#  'PARTLY_CLOUDY',
#  'CLEAR_NIGHT',
#  'CLEAR_NIGHT',
#  'CLEAR_NIGHT',
#  'SUNNY',
#  'CLEAR_NIGHT',
#  'CLEAR_NIGHT',
#  'PARTLY_CLOUDY_NIGHT',
#  'CLOUDY_NIGHT',
#  'CLOUDY_NIGHT',
#  'RAIN',
#  'RAIN',
#  'CLOUDY',
#  'CLEAR_NIGHT',
#  'PARTLY_CLOUDY',
#  'PARTLY_CLOUDY',
#  'CLOUDY',
#  'CLEAR_NIGHT',
#  'SUNNY',
#  'RAIN',
#  'PARTLY_CLOUDY',
#  'CLOUDY_NIGHT',
#  'PARTLY_CLOUDY',
#  'RAIN',
#  'PARTLY_CLOUDY']

# %%
# Convert the list to a numpy array for convenience
data_array = np.array(condition_weather_list, dtype=object)

# Find the most frequent non-nan value
most_frequent = Counter(data_array[~pd.isna(data_array)]).most_common(1)[0][0]
most_frequent
# Out:
# 'CLEAR_NIGHT'

# %%
df['condition_weather'] = df['condition_weather'].fillna(most_frequent)

# %%
# Check for null values in each column
null_values = df.isnull().sum()

# Print the results
print(null_values)
# Out:
# home_team                 0
# away_team                 0
# home_team_code            0
# away_team_code            0
# home_score                0
# away_score                0
# home_penalty             29
# away_penalty             29
# home_score_total          0
# away_score_total          0
# winner                    5
# winner_reason             0
# year                      0
# date                      0
# date_time                 0
# utc_offset_hours          0
# group_name                7
# matchday_name             0
# condition_humidity        1
# condition_pitch           0
# condition_temperature     1
# condition_weather         0
# condition_wind_speed      1
# status                    0
# type                      0
# round                     0
# round_mode                0
# match_attendance          0
# stadium_id                0
# stadium_country_code      0
# stadium_capacity          0
# stadium_latitude          0
# stadium_longitude         0
# stadium_pitch_length      0
# stadium_pitch_width       0
# goals                     2
# penalties_missed         30
# penalties                29
# red_cards                29
# game_referees             0
# stadium_city              0
# stadium_name              0
# stadium_name_media        0
# stadium_name_official     0
# stadium_name_event        0
# stadium_name_sponsor      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

df['away_score'].plot(kind='hist', bins=20, title='away_score', ax=axes[0])
axes[0].spines[['top', 'right']].set_visible(False)

df['home_score'].plot(kind='hist', bins=20, title='home_score', ax=axes[1])
axes[1].spines[['top', 'right']].set_visible(False)

plt.show()

# %%
# pairplot of df
import seaborn as sns

sns.pairplot(df)
plt.show()

# %% [markdown]
# **Heatmaps to visualize the frequency distributions of match conditions like pitch and weather across different categories such as matchday, condition weather, and group name. These visualizations help in understanding how match conditions vary with different groupings.**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

fig, axes = plt.subplots(2, 2, figsize=(16, 16))

# First heatmap
df_2dhist_1 = pd.DataFrame({
    x_label: grp['condition_pitch'].value_counts()
    for x_label, grp in df.groupby('matchday_name')
})
sns.heatmap(df_2dhist_1, cmap='viridis', ax=axes[0, 0])
axes[0, 0].set_xlabel('matchday_name')
axes[0, 0].set_ylabel('condition_pitch')
axes[0, 0].set_title('Heatmap 1: matchday_name vs condition_pitch')

# Second heatmap
df_2dhist_2 = pd.DataFrame({
    x_label: grp['condition_weather'].value_counts()
    for x_label, grp in df.groupby('matchday_name')
})
sns.heatmap(df_2dhist_2, cmap='viridis', ax=axes[0, 1])
axes[0, 1].set_xlabel('matchday_name')
axes[0, 1].set_ylabel('condition_weather')
axes[0, 1].set_title('Heatmap 2: matchday_name vs condition_weather')

# Third heatmap
df_2dhist_3 = pd.DataFrame({
    x_label: grp['condition_pitch'].value_counts()
    for x_label, grp in df.groupby('condition_weather')
})
sns.heatmap(df_2dhist_3, cmap='viridis', ax=axes[1, 0])
axes[1, 0].set_xlabel('condition_weather')
axes[1, 0].set_ylabel('condition_pitch')
axes[1, 0].set_title('Heatmap 3: condition_weather vs condition_pitch')

# Fourth heatmap
df_2dhist_4 = pd.DataFrame({
    x_label: grp['condition_weather'].value_counts()
    for x_label, grp in df.groupby('group_name')
})
sns.heatmap(df_2dhist_4, cmap='viridis', ax=axes[1, 1])
axes[1, 1].set_xlabel('group_name')
axes[1, 1].set_ylabel('condition_weather')
axes[1, 1].set_title('Heatmap 4: group_name vs condition_weather')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# **Horizontal bar plots to visualize the frequency distribution of various match characteristics such as round, winner, winner reason, weather conditions, pitch conditions, and stadium name. These plots help in understanding the distribution of these categorical variables across the dataset.**

# %%
# Create a figure with 2 rows and 2 columns of subplots
fig, axes = plt.subplots(3, 2, figsize=(16, 16))

# Plot each graph on its respective subplot
df.groupby('round').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[0, 0])
df.groupby('winner').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[0, 1])
df.groupby('winner_reason').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[1, 0])
df.groupby('condition_weather').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[1, 1])
df.groupby('condition_pitch').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[2, 0])
df.groupby('stadium_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[2, 1])

# Hide the top and right spines for all subplots
for ax in axes.flat:
    ax.spines[['top', 'right']].set_visible(False)

# Set the x-axis label for all subplots
for ax in axes.flat:
    ax.set_xlabel('frequency')

# Adjust the spacing between subplots
plt.tight_layout()

# %% [markdown]
# **Violin plots to visualize the distribution of home and away scores against various categorical variables such as stadium, matchday, and group. These plots provide insights into the spread and density of scores across different conditions.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


rows = 3
cols = 2

figsize = (12, 2 * len(df['group_name'].unique()))
plt.figure(figsize=figsize)

plot_titles = [
    "Home Score vs Stadium",
    "Away Score vs Stadium",
    "Away Score vs Matchday",
    "Home Score vs Matchday",
    "Away Score vs Group",
    "Home Score vs Group"
]

# Loop through each position in the grid and create a violin plot
count = 1
for i in range(rows):
    for j in range(cols):
        if count > len(plot_titles):
            break

        if count <= 2:
            x_var = (['home_score', 'away_score'][count - 1])
            y_var = 'stadium_name'
            palette = 'Dark2'
        elif count <= 4:
            x_var = 'matchday_name'
            y_var = (['away_score', 'home_score'][count - 3])
            palette = 'viridis'
        else:
            x_var = 'group_name'
            y_var = (['away_score', 'home_score'][count - 5])
            palette = 'inferno'

        # Create the subplot at the current position
        ax = plt.subplot(rows, cols, count)

        # Create the violin plot using seaborn
        sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
        sns.despine(top=True, right=True)

        # Add title for each subplot
        ax.set_title(plot_titles[count - 1], fontsize=10)
        ax.set_xlabel(x_var, fontsize=8)  # Set x-axis label
        ax.set_ylabel(y_var, fontsize=8)  # Set y-axis label
        count += 1

# Adjust layout to prevent overlapping elements
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)

# %% [markdown]
# **Regression plots to explore the relationships between match attendance, stadium capacity, wind speed, temperature, and humidity. The plots help in understanding how these variables correlate with each other.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axs = plt.subplots(2, 2, figsize=(12, 10))

sns.regplot(x='match_attendance', y='stadium_capacity', data=df, ax=axs[0,0])
axs[0,0].set_title('Regression Plot of Stadium Capacity vs. Attendance')
axs[0,0].set_xlabel('Attendance')
axs[0,0].set_ylabel('Stadium Capacity')

sns.regplot(x='condition_wind_speed', y='condition_temperature', data=df, ax=axs[0,1])
axs[0,1].set_title('Regression Plot of Winner vs. Attendance')
axs[0,1].set_xlabel('Wind Speed')
axs[0,1].set_ylabel('Temperature')

sns.regplot(x='condition_wind_speed', y='condition_humidity', data=df, ax=axs[1,0])
axs[1,0].set_title('Regression Plot of Winner vs. Attendance')
axs[1,0].set_xlabel('Wind Speed')
axs[1,0].set_ylabel('Humidity')

sns.regplot(x='condition_humidity', y='condition_temperature', data=df, ax=axs[1,1])
axs[1,1].set_title('Regression Plot of Winner vs. Attendance')
axs[1,1].set_xlabel('Humidity')
axs[1,1].set_ylabel('Temperature')

plt.tight_layout()

plt.show()

# %% [markdown]
# **This section visualizes the distribution of match data for the columns
# winner, winner_reason, stadium_name, and condition_weather using pie charts. Each pie chart represents the proportion of different categories within these columns, providing insights into the distribution of match outcomes, reasons, venues, and weather conditions.**

# %%
import matplotlib.pyplot as plt

column_names = ['winner', 'winner_reason', 'stadium_name', 'condition_weather']

fig, axes = plt.subplots(2, 2, figsize=(16, 14))

# Loop through each column name and create a pie chart
for i, column_name in enumerate(column_names):
    ax = axes.flat[i]  # Get the current subplot
    df[column_name].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140, ax=ax)
    ax.set_title(f'Proportion of Matches by {column_name}')
    ax.set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Bar plots to analyze match attendance based on various factors such as home team score, winner, away team score, stadium name, and match round. It also visualizes the total stadium capacity by stadium name.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axs = plt.subplots(3, 2, figsize=(16, 14))  # Create a 3x2 grid of subplots

# Define color palettes
inferno_palette = sns.color_palette('inferno', n_colors=10)
plasma_palette = sns.color_palette('plasma', n_colors=10)
viridis_palette = sns.color_palette('viridis', n_colors=10)
dark2_palette = sns.color_palette('Dark2', n_colors=10)

# Plot 1: Match Attendance vs Home Team Score
df.groupby('home_score')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=inferno_palette, ax=axs[0, 0]
)
axs[0, 0].spines[['top', 'right']].set_visible(False)
axs[0, 0].set_xlabel('Home Team Score')
axs[0, 0].set_ylabel('Match Attendance')
axs[0, 0].set_title('Match Attendance vs Home Team Score')

# Plot 2: Match Attendance vs Winner
df.groupby('winner')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=inferno_palette, ax=axs[0, 1]
)
axs[0, 1].spines[['top', 'right']].set_visible(False)
axs[0, 1].set_xlabel('Winner')
axs[0, 1].set_ylabel('Match Attendance')
axs[0, 1].set_title('Match Attendance vs Winner')

# Plot 3: Match Attendance vs Away Team Score
df.groupby('away_score')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=plasma_palette, ax=axs[1, 0]
)
axs[1, 0].spines[['top', 'right']].set_visible(False)
axs[1, 0].set_xlabel('Away Team Score')
axs[1, 0].set_ylabel('Match Attendance')
axs[1, 0].set_title('Match Attendance vs Away Team Score')

# Plot 4: Total Stadium Capacity vs Stadium Name
df.groupby('stadium_name')['stadium_capacity'].sum().sort_values(ascending=False).plot(
    kind='bar', color=viridis_palette, ax=axs[1, 1]
)
axs[1, 1].spines[['top', 'right']].set_visible(False)
axs[1, 1].set_xlabel('Stadium Name')
axs[1, 1].set_ylabel('Total Capacity')
axs[1, 1].set_title('Total Stadium Capacity vs Stadium Name')

# Plot 5: Match Attendance vs Stadium Name
df.groupby('stadium_name')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=dark2_palette, ax=axs[2, 0]
)
axs[2, 0].spines[['top', 'right']].set_visible(False)
axs[2, 0].set_xlabel('Stadium Name')
axs[2, 0].set_ylabel('Match Attendance')
axs[2, 0].set_title('Match Attendance vs Stadium Name')

# Plot 6: Match Attendance vs Round
df.groupby('round')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=inferno_palette, ax=axs[2, 1]
)
axs[2, 1].spines[['top', 'right']].set_visible(False)  # Remove top and right spines
axs[2, 1].set_xlabel('Round')
axs[2, 1].set_ylabel('Match Attendance')
axs[2, 1].set_title('Match Attendance vs Round')

plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# **Swarm Plots to visualize the distributions and relationships between categorical variables in soccer matches. The heatmaps show how pitch conditions and weather vary across different match days, and how weather conditions relate to both pitch conditions and group names, providing insights into potential correlations or patterns in the data.**

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 16))

# Define the parameters for each swarm plot
parameters = [
    {'x': 'home_score', 'y': 'away_score', 'hue': 'winner', 'palette': 'viridis'},
    {'x': 'condition_temperature', 'y': 'condition_humidity', 'hue': 'stadium_name', 'palette': 'plasma'},
    {'x': 'matchday_name', 'y': 'winner', 'hue': 'group_name', 'palette': 'inferno'},
    {'x': 'round', 'y': 'winner', 'hue': 'condition_weather', 'palette': 'Dark2'},
]

for i, parameter in enumerate(parameters):
    ax = axes.flat[i]
    sns.swarmplot(data=df, x=parameter['x'], y=parameter['y'], hue=parameter['hue'], palette=parameter['palette'], ax=ax)
    ax.set_title(f'Swarm Plot of {parameter["y"]} vs. {parameter["x"]}')
    ax.set_xlabel(parameter['x'])
    ax.set_ylabel(parameter['y'])

plt.tight_layout()
plt.show()
