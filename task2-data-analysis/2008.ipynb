# %%
# !git clone https://dagshub.com/Omdena/TunisiaLocalChapter_UEFAEURO2024.git
# Out:
# Cloning into 'TunisiaLocalChapter_UEFAEURO2024'...
# remote: Enumerating objects: 739, done.
# remote: Counting objects: 100% (739/739), done.
# remote: Compressing objects: 100% (731/731), done.
# remote: Total 739 (delta 428), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (739/739), 49.70 MiB | 5.81 MiB/s, done.
# Resolving deltas: 100% (428/428), done.

# %%
cd TunisiaLocalChapter_UEFAEURO2024
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024

# %%
ls
# Out:
# Datasets/                        task2-data-analysis/
# EDA_match_team_statistics.ipynb  task3-machine-learning-modeling/
# README.md                        task4-tournament-impact-on-tourism/
# task1-data-collection/

# %%
cd Datasets
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets

# %%
ls
# Out:
#  archive/                                          match_events.csv
#  archive.zip                                       match_information.csv
#  cleaned_euro_football.csv                         match_line_ups.csv
#  euro2024_player_rankings.csv                      match_team_statistics.csv
#  euro2024_players.csv                              players_stats_uefa_scraper.csv
#  euro_cup_datasets.zip                             pre_match_information.csv
#  fifa_ranking-2024-04-04.csv                       README.md
#  FIFA_rankings_1992_2024.zip                       results.csv
# 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'   Upload/
#  international_results-master.zip

# %%
cd 'Football - Soccer - UEFA EURO, 1960 - 2024'
# Out:
# [Errno 2] No such file or directory: 'Football - Soccer - UEFA EURO, 1960 - 2024'
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets

# %%
# prompt: unzip 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'

# !unzip 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'
# Out:
# Archive:  Football - Soccer - UEFA EURO, 1960 - 2024.zip
#   inflating: euro_summary.csv
#   inflating: matches/matches/euro/1960.csv
#   inflating: matches/matches/euro/1964.csv
#   inflating: matches/matches/euro/1968.csv
#   inflating: matches/matches/euro/1972.csv
#   inflating: matches/matches/euro/1976.csv
#   inflating: matches/matches/euro/1980.csv
#   inflating: matches/matches/euro/1984.csv
#   inflating: matches/matches/euro/1988.csv
#   inflating: matches/matches/euro/1992.csv
#   inflating: matches/matches/euro/1996.csv
#   inflating: matches/matches/euro/2000.csv
#   inflating: matches/matches/euro/2004.csv
#   inflating: matches/matches/euro/2008.csv
#   inflating: matches/matches/euro/2012.csv
#   inflating: matches/matches/euro/2016.csv
#   inflating: matches/matches/euro/2020.csv
#   inflating: matches/matches/euro/2024.csv
#   inflating: matches/matches/friendly_2021-2024.csv
#   inflating: matches/matches/nations/2019.csv
#   inflating: matches/matches/nations/2021.csv
#   inflating: matches/matches/nations/2023.csv
#   inflating: matches/matches/qualifying_1960-2024.csv

# %%
ls
# Out:
#  archive/                                          matches/
#  archive.zip                                       match_events.csv
#  cleaned_euro_football.csv                         match_information.csv
#  euro2024_player_rankings.csv                      match_line_ups.csv
#  euro2024_players.csv                              match_team_statistics.csv
#  euro_cup_datasets.zip                             players_stats_uefa_scraper.csv
#  euro_summary.csv                                  pre_match_information.csv
#  fifa_ranking-2024-04-04.csv                       README.md
#  FIFA_rankings_1992_2024.zip                       results.csv
# 'Football - Soccer - UEFA EURO, 1960 - 2024.zip'   Upload/
#  international_results-master.zip

# %%
cd matches
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches

# %%
ls
# Out:
# matches/

# %%
cd matches
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches/matches

# %%
ls
# Out:
# euro/  friendly_2021-2024.csv  nations/  qualifying_1960-2024.csv

# %%
cd euro
# Out:
# /content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches/matches/euro

# %%
ls
# Out:
# 1960.csv  1968.csv  1976.csv  1984.csv  1992.csv  2000.csv  2008.csv  2016.csv  2024.csv
# 1964.csv  1972.csv  1980.csv  1988.csv  1996.csv  2004.csv  2012.csv  2020.csv

# %%
import pandas as pd
df = pd.read_csv("/content/TunisiaLocalChapter_UEFAEURO2024/Datasets/matches/matches/euro/2008.csv")
df
# Out:
#       home_team away_team home_team_code away_team_code  home_score  \
# 0       Germany     Spain            GER            ESP         0.0
# 1        Russia     Spain            RUS            ESP         0.0
# 2       Germany  Türki̇ye            GER            TUR         3.0
# 3         Spain     Italy            ESP            ITA         0.0
# 4   Netherlands    Russia            NED            RUS         1.0
# 5       Croatia  Türki̇ye            CRO            TUR         0.0
# 6      Portugal   Germany            POR            GER         2.0
# 7        Russia    Sweden            RUS            SWE         2.0
# 8        Greece     Spain            GRE            ESP         1.0
# 9        France     Italy            FRA            ITA         0.0
# 10  Netherlands   Romania            NED            ROU         2.0
# 11      Austria   Germany            AUT            GER         0.0
# 12       Poland   Croatia            POL            CRO         0.0
# 13     Türki̇ye   Czechia            TUR            CZE         3.0
# 14  Switzerland  Portugal            SUI            POR         2.0
# 15       Greece    Russia            GRE            RUS         0.0
# 16       Sweden     Spain            SWE            ESP         1.0
# 17  Netherlands    France            NED            FRA         4.0
# 18        Italy   Romania            ITA            ROU         1.0
# 19      Austria    Poland            AUT            POL         1.0
# 20      Croatia   Germany            CRO            GER         2.0
# 21  Switzerland  Türki̇ye            SUI            TUR         1.0
# 22      Czechia  Portugal            CZE            POR         1.0
# 23       Greece    Sweden            GRE            SWE         0.0
# 24        Spain    Russia            ESP            RUS         4.0
# 25  Netherlands     Italy            NED            ITA         3.0
# 26      Romania    France            ROU            FRA         0.0
# 27      Germany    Poland            GER            POL         2.0
# 28      Austria   Croatia            AUT            CRO         0.0
# 29     Portugal  Türki̇ye            POR            TUR         2.0
# 30  Switzerland   Czechia            SUI            CZE         0.0
#
#     away_score  home_penalty  away_penalty  home_score_total  \
# 0          1.0           NaN           NaN               0.0
# 1          3.0           NaN           NaN               0.0
# 2          2.0           NaN           NaN               3.0
# 3          0.0           4.0           2.0               0.0
# 4          1.0           NaN           NaN               1.0
# 5          0.0           1.0           3.0               1.0
# 6          3.0           NaN           NaN               2.0
# 7          0.0           NaN           NaN               2.0
# 8          2.0           NaN           NaN               1.0
# 9          2.0           NaN           NaN               0.0
# 10         0.0           NaN           NaN               2.0
# 11         1.0           NaN           NaN               0.0
# 12         1.0           NaN           NaN               0.0
# 13         2.0           NaN           NaN               3.0
# 14         0.0           NaN           NaN               2.0
# 15         1.0           NaN           NaN               0.0
# 16         2.0           NaN           NaN               1.0
# 17         1.0           NaN           NaN               4.0
# 18         1.0           NaN           NaN               1.0
# 19         1.0           NaN           NaN               1.0
# 20         1.0           NaN           NaN               2.0
# 21         2.0           NaN           NaN               1.0
# 22         3.0           NaN           NaN               1.0
# 23         2.0           NaN           NaN               0.0
# 24         1.0           NaN           NaN               4.0
# 25         0.0           NaN           NaN               3.0
# 26         0.0           NaN           NaN               0.0
# 27         0.0           NaN           NaN               2.0
# 28         1.0           NaN           NaN               0.0
# 29         0.0           NaN           NaN               2.0
# 30         1.0           NaN           NaN               0.0
#
#     away_score_total  ...                                   penalties_missed  \
# 0                1.0  ...                                                NaN
# 1                3.0  ...                                                NaN
# 2                2.0  ...                                                NaN
# 3                0.0  ...                                                NaN
# 4                3.0  ...                                                NaN
# 5                1.0  ...                                                NaN
# 6                3.0  ...                                                NaN
# 7                0.0  ...                                                NaN
# 8                2.0  ...                                                NaN
# 9                2.0  ...                                                NaN
# 10               0.0  ...                                                NaN
# 11               1.0  ...                                                NaN
# 12               1.0  ...                                                NaN
# 13               2.0  ...                                                NaN
# 14               0.0  ...                                                NaN
# 15               1.0  ...                                                NaN
# 16               2.0  ...                                                NaN
# 17               1.0  ...                                                NaN
# 18               1.0  ...  [{'phase': 'SECOND_HALF', 'time': {'minute': 8...
# 19               1.0  ...                                                NaN
# 20               1.0  ...                                                NaN
# 21               2.0  ...                                                NaN
# 22               3.0  ...                                                NaN
# 23               2.0  ...                                                NaN
# 24               1.0  ...                                                NaN
# 25               0.0  ...                                                NaN
# 26               0.0  ...                                                NaN
# 27               0.0  ...                                                NaN
# 28               1.0  ...                                                NaN
# 29               0.0  ...                                                NaN
# 30               1.0  ...                                                NaN
#
#                                             penalties  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 4                                                 NaN
# 5   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                             red_cards  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  [{'phase': 'SECOND_HALF', 'time': {'injuryMinu...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  [{'phase': 'SECOND_HALF', 'time': {'injuryMinu...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                         game_referees stadium_city  \
# 0   [{'name': 'Jaap Uilenberg', 'role': 'REFEREE_O...       Vienna
# 1   [{'name': 'Kyros Vassaras', 'role': 'FOURTH_OF...       Vienna
# 2   [{'name': 'Stéphane Cuhat', 'role': 'ASSISTANT...        Basel
# 3   [{'name': 'Volker Wezel', 'role': 'ASSISTANT_R...       Vienna
# 4   [{'name': 'Martin Balko', 'role': 'ASSISTANT_R...        Basel
# 5   [{'name': 'Alessandro Griselli', 'role': 'ASSI...       Vienna
# 6   [{'name': 'Marc Batta', 'role': 'REFEREE_OBSER...        Basel
# 7   [{'name': 'Liutauras Varanavičius', 'role': 'U...    Innsbruck
# 8   [{'name': 'Darren Cann', 'role': 'ASSISTANT_RE...     Salzburg
# 9   [{'name': 'Viktor Kassai', 'role': 'FOURTH_OFF...       Zurich
# 10  [{'name': 'Craig Thomson', 'role': 'FOURTH_OFF...         Bern
# 11  [{'name': 'Sergey Zuev', 'role': 'REFEREE_OBSE...       Vienna
# 12  [{'name': 'Dane Jošt', 'role': 'UEFA_DELEGATE'...   Klagenfurt
# 13  [{'name': 'Henrik Andren', 'role': 'ASSISTANT_...       Geneva
# 14  [{'name': 'Markus Mayr', 'role': 'ASSISTANT_RE...        Basel
# 15  [{'name': 'Paolo Calcagno', 'role': 'ASSISTANT...     Salzburg
# 16  [{'name': 'Adrianus Inia', 'role': 'ASSISTANT_...    Innsbruck
# 17  [{'name': 'Volker Wezel', 'role': 'ASSISTANT_R...         Bern
# 18  [{'name': 'Dennis Cruise', 'role': 'UEFA_DELEG...       Zurich
# 19  [{'name': 'Howard Webb', 'role': 'REFEREE', 'n...       Vienna
# 20  [{'name': 'Stéphane Lannoy', 'role': 'FOURTH_O...   Klagenfurt
# 21  [{'name': 'Damir Skomina', 'role': 'FOURTH_OFF...        Basel
# 22  [{'name': 'Dane Jošt', 'role': 'UEFA_DELEGATE'...       Geneva
# 23  [{'name': 'Stéphane Cuhat', 'role': 'ASSISTANT...     Salzburg
# 24  [{'name': 'Egon Bereuter', 'role': 'ASSISTANT_...    Innsbruck
# 25  [{'name': 'Henrik Andren', 'role': 'ASSISTANT_...         Bern
# 26  [{'name': 'Jesús Calvo Guadamuro', 'role': 'AS...       Zurich
# 27  [{'name': 'Tom Henning Øvrebø', 'role': 'REFER...   Klagenfurt
# 28  [{'name': 'Adrianus Inia', 'role': 'ASSISTANT_...       Vienna
# 29  [{'name': 'Viktor Kassai', 'role': 'FOURTH_OFF...       Geneva
# 30  [{'name': 'Jozef Marko', 'role': 'REFEREE_OBSE...        Basel
#
#             stadium_name    stadium_name_media stadium_name_official  \
# 0   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 1   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 2         St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 3   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 4         St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 5   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 6         St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 7   Tivoli Stadion Tirol            Tivoli Neu  Tivoli Stadion Tirol
# 8       Stadion Salzburg      Stadion Salzburg      Stadion Salzburg
# 9     Stadion Letzigrund    Stadion Letzigrund    Stadion Letzigrund
# 10      Stadion Wankdorf      Stadion Wankdorf      Stadion Wankdorf
# 11  Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 12    Wörthersee Stadion    Wörthersee Stadion    Wörthersee Stadion
# 13       Stade de Genève       Stade de Genève       Stade de Genève
# 14        St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 15      Stadion Salzburg      Stadion Salzburg      Stadion Salzburg
# 16  Tivoli Stadion Tirol            Tivoli Neu  Tivoli Stadion Tirol
# 17      Stadion Wankdorf      Stadion Wankdorf      Stadion Wankdorf
# 18    Stadion Letzigrund    Stadion Letzigrund    Stadion Letzigrund
# 19  Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 20    Wörthersee Stadion    Wörthersee Stadion    Wörthersee Stadion
# 21        St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 22       Stade de Genève       Stade de Genève       Stade de Genève
# 23      Stadion Salzburg      Stadion Salzburg      Stadion Salzburg
# 24  Tivoli Stadion Tirol            Tivoli Neu  Tivoli Stadion Tirol
# 25      Stadion Wankdorf      Stadion Wankdorf      Stadion Wankdorf
# 26    Stadion Letzigrund    Stadion Letzigrund    Stadion Letzigrund
# 27    Wörthersee Stadion    Wörthersee Stadion    Wörthersee Stadion
# 28  Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 29       Stade de Genève       Stade de Genève       Stade de Genève
# 30        St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
#
#       stadium_name_event  stadium_name_sponsor
# 0   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 1   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 2         St. Jakob-Park        St. Jakob-Park
# 3   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 4         St. Jakob-Park        St. Jakob-Park
# 5   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 6         St. Jakob-Park        St. Jakob-Park
# 7   Tivoli Stadion Tirol  Tivoli Stadion Tirol
# 8       Stadion Salzburg        Red Bull Arena
# 9     Stadion Letzigrund   Stadion Letzigrund
# 10      Stadion Wankdorf      Stadion Wankdorf
# 11  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 12    Wörthersee Stadion        28 Black Arena
# 13       Stade de Genève       Stade de Genève
# 14        St. Jakob-Park        St. Jakob-Park
# 15      Stadion Salzburg        Red Bull Arena
# 16  Tivoli Stadion Tirol  Tivoli Stadion Tirol
# 17      Stadion Wankdorf      Stadion Wankdorf
# 18    Stadion Letzigrund   Stadion Letzigrund
# 19  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 20    Wörthersee Stadion        28 Black Arena
# 21        St. Jakob-Park        St. Jakob-Park
# 22       Stade de Genève       Stade de Genève
# 23      Stadion Salzburg        Red Bull Arena
# 24  Tivoli Stadion Tirol  Tivoli Stadion Tirol
# 25      Stadion Wankdorf      Stadion Wankdorf
# 26    Stadion Letzigrund   Stadion Letzigrund
# 27    Wörthersee Stadion        28 Black Arena
# 28  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 29       Stade de Genève       Stade de Genève
# 30        St. Jakob-Park        St. Jakob-Park
#
# [31 rows x 46 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 46 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   home_team              31 non-null     object
#  1   away_team              31 non-null     object
#  2   home_team_code         31 non-null     object
#  3   away_team_code         31 non-null     object
#  4   home_score             31 non-null     float64
#  5   away_score             31 non-null     float64
#  6   home_penalty           2 non-null      float64
#  7   away_penalty           2 non-null      float64
#  8   home_score_total       31 non-null     float64
#  9   away_score_total       31 non-null     float64
#  10  winner                 28 non-null     object
#  11  winner_reason          31 non-null     object
#  12  year                   31 non-null     int64
#  13  date                   31 non-null     object
#  14  date_time              31 non-null     object
#  15  utc_offset_hours       31 non-null     float64
#  16  group_name             24 non-null     object
#  17  matchday_name          31 non-null     object
#  18  condition_humidity     31 non-null     float64
#  19  condition_pitch        31 non-null     object
#  20  condition_temperature  31 non-null     float64
#  21  condition_weather      31 non-null     object
#  22  condition_wind_speed   31 non-null     float64
#  23  status                 31 non-null     object
#  24  type                   31 non-null     object
#  25  round                  31 non-null     object
#  26  round_mode             31 non-null     object
#  27  match_attendance       31 non-null     float64
#  28  stadium_id             31 non-null     int64
#  29  stadium_country_code   31 non-null     object
#  30  stadium_capacity       31 non-null     float64
#  31  stadium_latitude       31 non-null     float64
#  32  stadium_longitude      31 non-null     float64
#  33  stadium_pitch_length   31 non-null     float64
#  34  stadium_pitch_width    31 non-null     float64
#  35  goals                  29 non-null     object
#  36  penalties_missed       1 non-null      object
#  37  penalties              2 non-null      object
#  38  red_cards              3 non-null      object
#  39  game_referees          31 non-null     object
#  40  stadium_city           31 non-null     object
#  41  stadium_name           31 non-null     object
#  42  stadium_name_media     31 non-null     object
#  43  stadium_name_official  31 non-null     object
#  44  stadium_name_event     31 non-null     object
#  45  stadium_name_sponsor   31 non-null     object
# dtypes: float64(16), int64(2), object(28)
# memory usage: 11.3+ KB

# %%
missing_values = df.isnull().sum()
print(missing_values)
# Out:
# home_team                 0
# away_team                 0
# home_team_code            0
# away_team_code            0
# home_score                0
# away_score                0
# home_penalty             29
# away_penalty             29
# home_score_total          0
# away_score_total          0
# winner                    3
# winner_reason             0
# year                      0
# date                      0
# date_time                 0
# utc_offset_hours          0
# group_name                7
# matchday_name             0
# condition_humidity        0
# condition_pitch           0
# condition_temperature     0
# condition_weather         0
# condition_wind_speed      0
# status                    0
# type                      0
# round                     0
# round_mode                0
# match_attendance          0
# stadium_id                0
# stadium_country_code      0
# stadium_capacity          0
# stadium_latitude          0
# stadium_longitude         0
# stadium_pitch_length      0
# stadium_pitch_width       0
# goals                     2
# penalties_missed         30
# penalties                29
# red_cards                28
# game_referees             0
# stadium_city              0
# stadium_name              0
# stadium_name_media        0
# stadium_name_official     0
# stadium_name_event        0
# stadium_name_sponsor      0
# dtype: int64

# %%
df.describe()
# Out:
#        home_score  away_score  home_penalty  away_penalty  home_score_total  \
# count   31.000000   31.000000       2.00000      2.000000         31.000000
# mean     1.225806    1.129032       2.50000      2.500000          1.258065
# std      1.257237    0.957146       2.12132      0.707107          1.237410
# min      0.000000    0.000000       1.00000      2.000000          0.000000
# 25%      0.000000    0.000000       1.75000      2.250000          0.000000
# 50%      1.000000    1.000000       2.50000      2.500000          1.000000
# 75%      2.000000    2.000000       3.25000      2.750000          2.000000
# max      4.000000    3.000000       4.00000      3.000000          4.000000
#
#        away_score_total    year  utc_offset_hours  condition_humidity  \
# count         31.000000    31.0              31.0           31.000000
# mean           1.225806  2008.0               2.0           57.387097
# std            0.990275     0.0               0.0           16.837809
# min            0.000000  2008.0               2.0           33.000000
# 25%            0.500000  2008.0               2.0           46.000000
# 50%            1.000000  2008.0               2.0           53.000000
# 75%            2.000000  2008.0               2.0           67.500000
# max            3.000000  2008.0               2.0           88.000000
#
#        condition_temperature  condition_wind_speed  match_attendance  \
# count              31.000000             31.000000         31.000000
# mean               20.612903             27.967742      36888.032258
# std                 5.077253             18.449000       8705.133939
# min                12.000000              7.000000      29016.000000
# 25%                16.500000             12.000000      30585.000000
# 50%                21.000000             23.000000      30883.000000
# 75%                23.500000             36.500000      39730.000000
# max                31.000000             75.000000      51428.000000
#
#          stadium_id  stadium_capacity  stadium_latitude  stadium_longitude  \
# count     31.000000         31.000000         31.000000          31.000000
# mean   72463.354839      33372.645161         47.397278          11.064920
# std    10642.022660      10765.445866          0.637541           3.856645
# min    62085.000000      14932.000000         46.177997           6.127283
# 25%    63171.000000      26000.000000         46.963119           7.620125
# 50%    63175.000000      31500.000000         47.541636          11.411169
# 75%    83180.000000      36000.000000         47.816286          14.277495
# max    89590.000000      49898.000000         48.207189          16.420508
#
#        stadium_pitch_length  stadium_pitch_width
# count                  31.0                 31.0
# mean                  105.0                 68.0
# std                     0.0                  0.0
# min                   105.0                 68.0
# 25%                   105.0                 68.0
# 50%                   105.0                 68.0
# 75%                   105.0                 68.0
# max                   105.0                 68.0

# %%
import pandas as pd
# View all columns of the dataframe
pd.set_option('display.max_columns', None)
df
# Out:
#       home_team away_team home_team_code away_team_code  home_score  \
# 0       Germany     Spain            GER            ESP         0.0
# 1        Russia     Spain            RUS            ESP         0.0
# 2       Germany  Türki̇ye            GER            TUR         3.0
# 3         Spain     Italy            ESP            ITA         0.0
# 4   Netherlands    Russia            NED            RUS         1.0
# 5       Croatia  Türki̇ye            CRO            TUR         0.0
# 6      Portugal   Germany            POR            GER         2.0
# 7        Russia    Sweden            RUS            SWE         2.0
# 8        Greece     Spain            GRE            ESP         1.0
# 9        France     Italy            FRA            ITA         0.0
# 10  Netherlands   Romania            NED            ROU         2.0
# 11      Austria   Germany            AUT            GER         0.0
# 12       Poland   Croatia            POL            CRO         0.0
# 13     Türki̇ye   Czechia            TUR            CZE         3.0
# 14  Switzerland  Portugal            SUI            POR         2.0
# 15       Greece    Russia            GRE            RUS         0.0
# 16       Sweden     Spain            SWE            ESP         1.0
# 17  Netherlands    France            NED            FRA         4.0
# 18        Italy   Romania            ITA            ROU         1.0
# 19      Austria    Poland            AUT            POL         1.0
# 20      Croatia   Germany            CRO            GER         2.0
# 21  Switzerland  Türki̇ye            SUI            TUR         1.0
# 22      Czechia  Portugal            CZE            POR         1.0
# 23       Greece    Sweden            GRE            SWE         0.0
# 24        Spain    Russia            ESP            RUS         4.0
# 25  Netherlands     Italy            NED            ITA         3.0
# 26      Romania    France            ROU            FRA         0.0
# 27      Germany    Poland            GER            POL         2.0
# 28      Austria   Croatia            AUT            CRO         0.0
# 29     Portugal  Türki̇ye            POR            TUR         2.0
# 30  Switzerland   Czechia            SUI            CZE         0.0
#
#     away_score  home_penalty  away_penalty  home_score_total  \
# 0          1.0           NaN           NaN               0.0
# 1          3.0           NaN           NaN               0.0
# 2          2.0           NaN           NaN               3.0
# 3          0.0           4.0           2.0               0.0
# 4          1.0           NaN           NaN               1.0
# 5          0.0           1.0           3.0               1.0
# 6          3.0           NaN           NaN               2.0
# 7          0.0           NaN           NaN               2.0
# 8          2.0           NaN           NaN               1.0
# 9          2.0           NaN           NaN               0.0
# 10         0.0           NaN           NaN               2.0
# 11         1.0           NaN           NaN               0.0
# 12         1.0           NaN           NaN               0.0
# 13         2.0           NaN           NaN               3.0
# 14         0.0           NaN           NaN               2.0
# 15         1.0           NaN           NaN               0.0
# 16         2.0           NaN           NaN               1.0
# 17         1.0           NaN           NaN               4.0
# 18         1.0           NaN           NaN               1.0
# 19         1.0           NaN           NaN               1.0
# 20         1.0           NaN           NaN               2.0
# 21         2.0           NaN           NaN               1.0
# 22         3.0           NaN           NaN               1.0
# 23         2.0           NaN           NaN               0.0
# 24         1.0           NaN           NaN               4.0
# 25         0.0           NaN           NaN               3.0
# 26         0.0           NaN           NaN               0.0
# 27         0.0           NaN           NaN               2.0
# 28         1.0           NaN           NaN               0.0
# 29         0.0           NaN           NaN               2.0
# 30         1.0           NaN           NaN               0.0
#
#     away_score_total       winner      winner_reason  year        date  \
# 0                1.0        Spain        WIN_REGULAR  2008  2008-06-29
# 1                3.0        Spain        WIN_REGULAR  2008  2008-06-26
# 2                2.0      Germany        WIN_REGULAR  2008  2008-06-25
# 3                0.0        Spain   WIN_ON_PENALTIES  2008  2008-06-22
# 4                3.0       Russia  WIN_ON_EXTRA_TIME  2008  2008-06-21
# 5                1.0     Türki̇ye   WIN_ON_PENALTIES  2008  2008-06-20
# 6                3.0      Germany        WIN_REGULAR  2008  2008-06-19
# 7                0.0       Russia        WIN_REGULAR  2008  2008-06-18
# 8                2.0        Spain        WIN_REGULAR  2008  2008-06-18
# 9                2.0        Italy        WIN_REGULAR  2008  2008-06-17
# 10               0.0  Netherlands        WIN_REGULAR  2008  2008-06-17
# 11               1.0      Germany        WIN_REGULAR  2008  2008-06-16
# 12               1.0      Croatia        WIN_REGULAR  2008  2008-06-16
# 13               2.0     Türki̇ye        WIN_REGULAR  2008  2008-06-15
# 14               0.0  Switzerland        WIN_REGULAR  2008  2008-06-15
# 15               1.0       Russia        WIN_REGULAR  2008  2008-06-14
# 16               2.0        Spain        WIN_REGULAR  2008  2008-06-14
# 17               1.0  Netherlands        WIN_REGULAR  2008  2008-06-13
# 18               1.0          NaN               DRAW  2008  2008-06-13
# 19               1.0          NaN               DRAW  2008  2008-06-12
# 20               1.0      Croatia        WIN_REGULAR  2008  2008-06-12
# 21               2.0     Türki̇ye        WIN_REGULAR  2008  2008-06-11
# 22               3.0     Portugal        WIN_REGULAR  2008  2008-06-11
# 23               2.0       Sweden        WIN_REGULAR  2008  2008-06-10
# 24               1.0        Spain        WIN_REGULAR  2008  2008-06-10
# 25               0.0  Netherlands        WIN_REGULAR  2008  2008-06-09
# 26               0.0          NaN               DRAW  2008  2008-06-09
# 27               0.0      Germany        WIN_REGULAR  2008  2008-06-08
# 28               1.0      Croatia        WIN_REGULAR  2008  2008-06-08
# 29               0.0     Portugal        WIN_REGULAR  2008  2008-06-07
# 30               1.0      Czechia        WIN_REGULAR  2008  2008-06-07
#
#                date_time  utc_offset_hours group_name matchday_name  \
# 0   2008-06-29T18:45:00Z               2.0        NaN           MD6
# 1   2008-06-26T18:45:00Z               2.0        NaN           MD5
# 2   2008-06-25T18:45:00Z               2.0        NaN           MD5
# 3   2008-06-22T18:45:00Z               2.0        NaN           MD4
# 4   2008-06-21T18:45:00Z               2.0        NaN           MD4
# 5   2008-06-20T18:45:00Z               2.0        NaN           MD4
# 6   2008-06-19T18:45:00Z               2.0        NaN           MD4
# 7   2008-06-18T18:45:00Z               2.0    Group D           MD3
# 8   2008-06-18T18:45:00Z               2.0    Group D           MD3
# 9   2008-06-17T18:45:00Z               2.0    Group C           MD3
# 10  2008-06-17T18:45:00Z               2.0    Group C           MD3
# 11  2008-06-16T18:45:00Z               2.0    Group B           MD3
# 12  2008-06-16T18:45:00Z               2.0    Group B           MD3
# 13  2008-06-15T18:45:00Z               2.0    Group A           MD3
# 14  2008-06-15T18:45:00Z               2.0    Group A           MD3
# 15  2008-06-14T18:45:00Z               2.0    Group D           MD2
# 16  2008-06-14T16:00:00Z               2.0    Group D           MD2
# 17  2008-06-13T18:45:00Z               2.0    Group C           MD2
# 18  2008-06-13T16:00:00Z               2.0    Group C           MD2
# 19  2008-06-12T18:45:00Z               2.0    Group B           MD2
# 20  2008-06-12T16:00:00Z               2.0    Group B           MD2
# 21  2008-06-11T18:45:00Z               2.0    Group A           MD2
# 22  2008-06-11T16:00:00Z               2.0    Group A           MD2
# 23  2008-06-10T18:45:00Z               2.0    Group D           MD1
# 24  2008-06-10T16:00:00Z               2.0    Group D           MD1
# 25  2008-06-09T18:45:00Z               2.0    Group C           MD1
# 26  2008-06-09T16:00:00Z               2.0    Group C           MD1
# 27  2008-06-08T18:45:00Z               2.0    Group B           MD1
# 28  2008-06-08T16:00:00Z               2.0    Group B           MD1
# 29  2008-06-07T18:45:00Z               2.0    Group A           MD1
# 30  2008-06-07T16:00:00Z               2.0    Group A           MD1
#
#     condition_humidity condition_pitch  condition_temperature  \
# 0                 44.0             DRY                   27.0
# 1                 83.0             WET                   23.0
# 2                 61.0             DRY                   26.0
# 3                 46.0             DRY                   31.0
# 4                 48.0             DRY                   28.0
# 5                 39.0             DRY                   28.0
# 6                 53.0             DRY                   22.0
# 7                 48.0             DRY                   23.0
# 8                 49.0             DRY                   20.0
# 9                 77.0             DRY                   16.0
# 10                78.0             WET                   17.0
# 11                53.0             DRY                   21.0
# 12                48.0             DRY                   22.0
# 13                62.0            DAMP                   15.0
# 14                83.0             DRY                   12.0
# 15                34.0             DRY                   13.0
# 16                34.0             DRY                   19.0
# 17                62.0            DAMP                   14.0
# 18                48.0             DRY                   15.0
# 19                46.0             DRY                   21.0
# 20                67.0             WET                   21.0
# 21                88.0             WET                   18.0
# 22                53.0             DRY                   21.0
# 23                44.0             DRY                   24.0
# 24                33.0             DRY                   28.0
# 25                68.0             DRY                   19.0
# 26                47.0             DRY                   23.0
# 27                45.0             DRY                   24.0
# 28                64.0             DRY                   21.0
# 29                86.0            DAMP                   14.0
# 30                88.0             DRY                   13.0
#
#       condition_weather  condition_wind_speed    status         type  \
# 0                 SUNNY                   7.0  FINISHED       SINGLE
# 1                CLOUDY                  63.0  FINISHED       SINGLE
# 2         PARTLY_CLOUDY                  30.0  FINISHED       SINGLE
# 3                 SUNNY                  53.0  FINISHED       SINGLE
# 4                 SUNNY                  15.0  FINISHED       SINGLE
# 5                 SUNNY                  65.0  FINISHED       SINGLE
# 6                 SUNNY                  49.0  FINISHED       SINGLE
# 7                 SUNNY                  10.0  FINISHED  GROUP_STAGE
# 8         PARTLY_CLOUDY                  22.0  FINISHED  GROUP_STAGE
# 9                  RAIN                  28.0  FINISHED  GROUP_STAGE
# 10         CLOUDY_NIGHT                  35.0  FINISHED  GROUP_STAGE
# 11        PARTLY_CLOUDY                  35.0  FINISHED  GROUP_STAGE
# 12        PARTLY_CLOUDY                  10.0  FINISHED  GROUP_STAGE
# 13         CLOUDY_NIGHT                  22.0  FINISHED  GROUP_STAGE
# 14               CLOUDY                  28.0  FINISHED  GROUP_STAGE
# 15               CLOUDY                  23.0  FINISHED  GROUP_STAGE
# 16               CLOUDY                  10.0  FINISHED  GROUP_STAGE
# 17  PARTLY_CLOUDY_NIGHT                   8.0  FINISHED  GROUP_STAGE
# 18        PARTLY_CLOUDY                  14.0  FINISHED  GROUP_STAGE
# 19                SUNNY                  75.0  FINISHED  GROUP_STAGE
# 20               CLOUDY                  10.0  FINISHED  GROUP_STAGE
# 21                 RAIN                  14.0  FINISHED  GROUP_STAGE
# 22        PARTLY_CLOUDY                  44.0  FINISHED  GROUP_STAGE
# 23               CLOUDY                  16.0  FINISHED  GROUP_STAGE
# 24                SUNNY                  10.0  FINISHED  GROUP_STAGE
# 25  PARTLY_CLOUDY_NIGHT                  38.0  FINISHED  GROUP_STAGE
# 26        PARTLY_CLOUDY                  40.0  FINISHED  GROUP_STAGE
# 27                SUNNY                  10.0  FINISHED  GROUP_STAGE
# 28        PARTLY_CLOUDY                  18.0  FINISHED  GROUP_STAGE
# 29         CLOUDY_NIGHT                  35.0  FINISHED  GROUP_STAGE
# 30               CLOUDY                  30.0  FINISHED  GROUP_STAGE
#
#               round round_mode  match_attendance  stadium_id  \
# 0             FINAL      FINAL           51428.0       62085
# 1         SEMIFINAL  KNOCK_OUT           51428.0       62085
# 2         SEMIFINAL  KNOCK_OUT           39374.0       63171
# 3    QUARTER_FINALS  KNOCK_OUT           51178.0       62085
# 4    QUARTER_FINALS  KNOCK_OUT           38374.0       63171
# 5    QUARTER_FINALS  KNOCK_OUT           51428.0       62085
# 6    QUARTER_FINALS  KNOCK_OUT           39374.0       63171
# 7   GROUP_STANDINGS      GROUP           30772.0       77473
# 8   GROUP_STANDINGS      GROUP           30883.0       83487
# 9   GROUP_STANDINGS      GROUP           30585.0       63175
# 10  GROUP_STANDINGS      GROUP           30777.0       89590
# 11  GROUP_STANDINGS      GROUP           51428.0       62085
# 12  GROUP_STANDINGS      GROUP           30461.0       80676
# 13  GROUP_STANDINGS      GROUP           29016.0       83180
# 14  GROUP_STANDINGS      GROUP           39730.0       63171
# 15  GROUP_STANDINGS      GROUP           31063.0       83487
# 16  GROUP_STANDINGS      GROUP           30772.0       77473
# 17  GROUP_STANDINGS      GROUP           30777.0       89590
# 18  GROUP_STANDINGS      GROUP           30585.0       63175
# 19  GROUP_STANDINGS      GROUP           51428.0       62085
# 20  GROUP_STANDINGS      GROUP           30461.0       80676
# 21  GROUP_STANDINGS      GROUP           39730.0       63171
# 22  GROUP_STANDINGS      GROUP           29016.0       83180
# 23  GROUP_STANDINGS      GROUP           31063.0       83487
# 24  GROUP_STANDINGS      GROUP           30772.0       77473
# 25  GROUP_STANDINGS      GROUP           30777.0       89590
# 26  GROUP_STANDINGS      GROUP           30585.0       63175
# 27  GROUP_STANDINGS      GROUP           30000.0       80676
# 28  GROUP_STANDINGS      GROUP           51428.0       62085
# 29  GROUP_STANDINGS      GROUP           29106.0       83180
# 30  GROUP_STANDINGS      GROUP           39730.0       63171
#
#    stadium_country_code  stadium_capacity  stadium_latitude  \
# 0                   AUT           49898.0         48.207189
# 1                   AUT           49898.0         48.207189
# 2                   SUI           36000.0         47.541636
# 3                   AUT           49898.0         48.207189
# 4                   SUI           36000.0         47.541636
# 5                   AUT           49898.0         48.207189
# 6                   SUI           36000.0         47.541636
# 7                   AUT           14932.0         47.256014
# 8                   AUT           30071.0         47.816286
# 9                   SUI           24056.0         47.382803
# 10                  SUI           31500.0         46.963119
# 11                  AUT           49898.0         48.207189
# 12                  AUT           29863.0         46.608945
# 13                  SUI           26000.0         46.177997
# 14                  SUI           36000.0         47.541636
# 15                  AUT           30071.0         47.816286
# 16                  AUT           14932.0         47.256014
# 17                  SUI           31500.0         46.963119
# 18                  SUI           24056.0         47.382803
# 19                  AUT           49898.0         48.207189
# 20                  AUT           29863.0         46.608945
# 21                  SUI           36000.0         47.541636
# 22                  SUI           26000.0         46.177997
# 23                  AUT           30071.0         47.816286
# 24                  AUT           14932.0         47.256014
# 25                  SUI           31500.0         46.963119
# 26                  SUI           24056.0         47.382803
# 27                  AUT           29863.0         46.608945
# 28                  AUT           49898.0         48.207189
# 29                  SUI           26000.0         46.177997
# 30                  SUI           36000.0         47.541636
#
#     stadium_longitude  stadium_pitch_length  stadium_pitch_width  \
# 0           16.420508                 105.0                 68.0
# 1           16.420508                 105.0                 68.0
# 2            7.620125                 105.0                 68.0
# 3           16.420508                 105.0                 68.0
# 4            7.620125                 105.0                 68.0
# 5           16.420508                 105.0                 68.0
# 6            7.620125                 105.0                 68.0
# 7           11.411169                 105.0                 68.0
# 8           12.998197                 105.0                 68.0
# 9            8.503719                 105.0                 68.0
# 10           7.464875                 105.0                 68.0
# 11          16.420508                 105.0                 68.0
# 12          14.277495                 105.0                 68.0
# 13           6.127283                 105.0                 68.0
# 14           7.620125                 105.0                 68.0
# 15          12.998197                 105.0                 68.0
# 16          11.411169                 105.0                 68.0
# 17           7.464875                 105.0                 68.0
# 18           8.503719                 105.0                 68.0
# 19          16.420508                 105.0                 68.0
# 20          14.277495                 105.0                 68.0
# 21           7.620125                 105.0                 68.0
# 22           6.127283                 105.0                 68.0
# 23          12.998197                 105.0                 68.0
# 24          11.411169                 105.0                 68.0
# 25           7.464875                 105.0                 68.0
# 26           8.503719                 105.0                 68.0
# 27          14.277495                 105.0                 68.0
# 28          16.420508                 105.0                 68.0
# 29           6.127283                 105.0                 68.0
# 30           7.620125                 105.0                 68.0
#
#                                                 goals  \
# 0   [{'phase': 'FIRST_HALF', 'time': {'minute': 33...
# 1   [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 2   [{'phase': 'FIRST_HALF', 'time': {'minute': 22...
# 3                                                 NaN
# 4   [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 5   [{'phase': 'EXTRA_TIME_SECOND_HALF', 'time': {...
# 6   [{'phase': 'FIRST_HALF', 'time': {'minute': 22...
# 7   [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 8   [{'phase': 'FIRST_HALF', 'time': {'minute': 42...
# 9   [{'phase': 'FIRST_HALF', 'time': {'minute': 25...
# 10  [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 11  [{'phase': 'SECOND_HALF', 'time': {'minute': 4...
# 12  [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 13  [{'phase': 'FIRST_HALF', 'time': {'minute': 34...
# 14  [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
# 15  [{'phase': 'FIRST_HALF', 'time': {'minute': 33...
# 16  [{'phase': 'FIRST_HALF', 'time': {'minute': 15...
# 17  [{'phase': 'FIRST_HALF', 'time': {'minute': 9,...
# 18  [{'phase': 'SECOND_HALF', 'time': {'minute': 5...
# 19  [{'phase': 'FIRST_HALF', 'time': {'minute': 30...
# 20  [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 21  [{'phase': 'FIRST_HALF', 'time': {'minute': 32...
# 22  [{'phase': 'FIRST_HALF', 'time': {'minute': 8,...
# 23  [{'phase': 'SECOND_HALF', 'time': {'minute': 6...
# 24  [{'phase': 'FIRST_HALF', 'time': {'minute': 20...
# 25  [{'phase': 'FIRST_HALF', 'time': {'minute': 26...
# 26                                                NaN
# 27  [{'phase': 'FIRST_HALF', 'time': {'minute': 20...
# 28  [{'phase': 'FIRST_HALF', 'time': {'minute': 4,...
# 29  [{'phase': 'SECOND_HALF', 'time': {'minute': 6...
# 30  [{'phase': 'SECOND_HALF', 'time': {'minute': 7...
#
#                                      penalties_missed  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18  [{'phase': 'SECOND_HALF', 'time': {'minute': 8...
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                             penalties  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 4                                                 NaN
# 5   [{'phase': 'PENALTY', 'time': {}, 'internation...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                             red_cards  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   [{'phase': 'FIRST_HALF', 'time': {'minute': 24...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  [{'phase': 'SECOND_HALF', 'time': {'injuryMinu...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  [{'phase': 'SECOND_HALF', 'time': {'injuryMinu...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
#
#                                         game_referees stadium_city  \
# 0   [{'name': 'Jaap Uilenberg', 'role': 'REFEREE_O...       Vienna
# 1   [{'name': 'Kyros Vassaras', 'role': 'FOURTH_OF...       Vienna
# 2   [{'name': 'Stéphane Cuhat', 'role': 'ASSISTANT...        Basel
# 3   [{'name': 'Volker Wezel', 'role': 'ASSISTANT_R...       Vienna
# 4   [{'name': 'Martin Balko', 'role': 'ASSISTANT_R...        Basel
# 5   [{'name': 'Alessandro Griselli', 'role': 'ASSI...       Vienna
# 6   [{'name': 'Marc Batta', 'role': 'REFEREE_OBSER...        Basel
# 7   [{'name': 'Liutauras Varanavičius', 'role': 'U...    Innsbruck
# 8   [{'name': 'Darren Cann', 'role': 'ASSISTANT_RE...     Salzburg
# 9   [{'name': 'Viktor Kassai', 'role': 'FOURTH_OFF...       Zurich
# 10  [{'name': 'Craig Thomson', 'role': 'FOURTH_OFF...         Bern
# 11  [{'name': 'Sergey Zuev', 'role': 'REFEREE_OBSE...       Vienna
# 12  [{'name': 'Dane Jošt', 'role': 'UEFA_DELEGATE'...   Klagenfurt
# 13  [{'name': 'Henrik Andren', 'role': 'ASSISTANT_...       Geneva
# 14  [{'name': 'Markus Mayr', 'role': 'ASSISTANT_RE...        Basel
# 15  [{'name': 'Paolo Calcagno', 'role': 'ASSISTANT...     Salzburg
# 16  [{'name': 'Adrianus Inia', 'role': 'ASSISTANT_...    Innsbruck
# 17  [{'name': 'Volker Wezel', 'role': 'ASSISTANT_R...         Bern
# 18  [{'name': 'Dennis Cruise', 'role': 'UEFA_DELEG...       Zurich
# 19  [{'name': 'Howard Webb', 'role': 'REFEREE', 'n...       Vienna
# 20  [{'name': 'Stéphane Lannoy', 'role': 'FOURTH_O...   Klagenfurt
# 21  [{'name': 'Damir Skomina', 'role': 'FOURTH_OFF...        Basel
# 22  [{'name': 'Dane Jošt', 'role': 'UEFA_DELEGATE'...       Geneva
# 23  [{'name': 'Stéphane Cuhat', 'role': 'ASSISTANT...     Salzburg
# 24  [{'name': 'Egon Bereuter', 'role': 'ASSISTANT_...    Innsbruck
# 25  [{'name': 'Henrik Andren', 'role': 'ASSISTANT_...         Bern
# 26  [{'name': 'Jesús Calvo Guadamuro', 'role': 'AS...       Zurich
# 27  [{'name': 'Tom Henning Øvrebø', 'role': 'REFER...   Klagenfurt
# 28  [{'name': 'Adrianus Inia', 'role': 'ASSISTANT_...       Vienna
# 29  [{'name': 'Viktor Kassai', 'role': 'FOURTH_OFF...       Geneva
# 30  [{'name': 'Jozef Marko', 'role': 'REFEREE_OBSE...        Basel
#
#             stadium_name    stadium_name_media stadium_name_official  \
# 0   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 1   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 2         St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 3   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 4         St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 5   Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 6         St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 7   Tivoli Stadion Tirol            Tivoli Neu  Tivoli Stadion Tirol
# 8       Stadion Salzburg      Stadion Salzburg      Stadion Salzburg
# 9     Stadion Letzigrund    Stadion Letzigrund    Stadion Letzigrund
# 10      Stadion Wankdorf      Stadion Wankdorf      Stadion Wankdorf
# 11  Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 12    Wörthersee Stadion    Wörthersee Stadion    Wörthersee Stadion
# 13       Stade de Genève       Stade de Genève       Stade de Genève
# 14        St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 15      Stadion Salzburg      Stadion Salzburg      Stadion Salzburg
# 16  Tivoli Stadion Tirol            Tivoli Neu  Tivoli Stadion Tirol
# 17      Stadion Wankdorf      Stadion Wankdorf      Stadion Wankdorf
# 18    Stadion Letzigrund    Stadion Letzigrund    Stadion Letzigrund
# 19  Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 20    Wörthersee Stadion    Wörthersee Stadion    Wörthersee Stadion
# 21        St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
# 22       Stade de Genève       Stade de Genève       Stade de Genève
# 23      Stadion Salzburg      Stadion Salzburg      Stadion Salzburg
# 24  Tivoli Stadion Tirol            Tivoli Neu  Tivoli Stadion Tirol
# 25      Stadion Wankdorf      Stadion Wankdorf      Stadion Wankdorf
# 26    Stadion Letzigrund    Stadion Letzigrund    Stadion Letzigrund
# 27    Wörthersee Stadion    Wörthersee Stadion    Wörthersee Stadion
# 28  Ernst-Happel-Stadion  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 29       Stade de Genève       Stade de Genève       Stade de Genève
# 30        St. Jakob-Park        St. Jakob-Park        St. Jakob-Park
#
#       stadium_name_event  stadium_name_sponsor
# 0   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 1   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 2         St. Jakob-Park        St. Jakob-Park
# 3   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 4         St. Jakob-Park        St. Jakob-Park
# 5   Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 6         St. Jakob-Park        St. Jakob-Park
# 7   Tivoli Stadion Tirol  Tivoli Stadion Tirol
# 8       Stadion Salzburg        Red Bull Arena
# 9     Stadion Letzigrund   Stadion Letzigrund
# 10      Stadion Wankdorf      Stadion Wankdorf
# 11  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 12    Wörthersee Stadion        28 Black Arena
# 13       Stade de Genève       Stade de Genève
# 14        St. Jakob-Park        St. Jakob-Park
# 15      Stadion Salzburg        Red Bull Arena
# 16  Tivoli Stadion Tirol  Tivoli Stadion Tirol
# 17      Stadion Wankdorf      Stadion Wankdorf
# 18    Stadion Letzigrund   Stadion Letzigrund
# 19  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 20    Wörthersee Stadion        28 Black Arena
# 21        St. Jakob-Park        St. Jakob-Park
# 22       Stade de Genève       Stade de Genève
# 23      Stadion Salzburg        Red Bull Arena
# 24  Tivoli Stadion Tirol  Tivoli Stadion Tirol
# 25      Stadion Wankdorf      Stadion Wankdorf
# 26    Stadion Letzigrund   Stadion Letzigrund
# 27    Wörthersee Stadion        28 Black Arena
# 28  Ernst-Happel-Stadion  Ernst-Happel-Stadion
# 29       Stade de Genève       Stade de Genève
# 30        St. Jakob-Park        St. Jakob-Park

# %% [markdown]
# Missing Values of coundition_pitch column are replaced by the most frequent entry of the column

# %%
condition_pitch_list = df['condition_pitch'].tolist()

# %%
from collections import Counter
import numpy as np
data_array = np.array(condition_pitch_list, dtype=object)
data_array
# Out:
# array(['DRY', 'WET', 'DRY', 'DRY', 'DRY', 'DRY', 'DRY', 'DRY', 'DRY',
#        'DRY', 'WET', 'DRY', 'DRY', 'DAMP', 'DRY', 'DRY', 'DRY', 'DAMP',
#        'DRY', 'DRY', 'WET', 'WET', 'DRY', 'DRY', 'DRY', 'DRY', 'DRY',
#        'DRY', 'DRY', 'DAMP', 'DRY'], dtype=object)

# %%
most_frequent = Counter(data_array[~pd.isna(data_array)]).most_common(1)[0][0]
most_frequent
# Out:
# 'DRY'

# %%
df['condition_pitch'] = df['condition_pitch'].fillna(most_frequent)

# %%
# Check for null values in each column
null_values = df.isnull().sum()

# Print the results
print(null_values)
# Out:
# home_team                 0
# away_team                 0
# home_team_code            0
# away_team_code            0
# home_score                0
# away_score                0
# home_penalty             29
# away_penalty             29
# home_score_total          0
# away_score_total          0
# winner                    3
# winner_reason             0
# year                      0
# date                      0
# date_time                 0
# utc_offset_hours          0
# group_name                7
# matchday_name             0
# condition_humidity        0
# condition_pitch           0
# condition_temperature     0
# condition_weather         0
# condition_wind_speed      0
# status                    0
# type                      0
# round                     0
# round_mode                0
# match_attendance          0
# stadium_id                0
# stadium_country_code      0
# stadium_capacity          0
# stadium_latitude          0
# stadium_longitude         0
# stadium_pitch_length      0
# stadium_pitch_width       0
# goals                     2
# penalties_missed         30
# penalties                29
# red_cards                28
# game_referees             0
# stadium_city              0
# stadium_name              0
# stadium_name_media        0
# stadium_name_official     0
# stadium_name_event        0
# stadium_name_sponsor      0
# dtype: int64

# %%
condition_weather_list = df['condition_weather'].tolist()
condition_weather_list
# Out:
# ['SUNNY',
#  'CLOUDY',
#  'PARTLY_CLOUDY',
#  'SUNNY',
#  'SUNNY',
#  'SUNNY',
#  'SUNNY',
#  'SUNNY',
#  'PARTLY_CLOUDY',
#  'RAIN',
#  'CLOUDY_NIGHT',
#  'PARTLY_CLOUDY',
#  'PARTLY_CLOUDY',
#  'CLOUDY_NIGHT',
#  'CLOUDY',
#  'CLOUDY',
#  'CLOUDY',
#  'PARTLY_CLOUDY_NIGHT',
#  'PARTLY_CLOUDY',
#  'SUNNY',
#  'CLOUDY',
#  'RAIN',
#  'PARTLY_CLOUDY',
#  'CLOUDY',
#  'SUNNY',
#  'PARTLY_CLOUDY_NIGHT',
#  'PARTLY_CLOUDY',
#  'SUNNY',
#  'PARTLY_CLOUDY',
#  'CLOUDY_NIGHT',
#  'CLOUDY']

# %%
# Convert the list to a numpy array for convenience
data_array = np.array(condition_weather_list, dtype=object)

# Find the most frequent non-nan value
most_frequent = Counter(data_array[~pd.isna(data_array)]).most_common(1)[0][0]
most_frequent
# Out:
# 'SUNNY'

# %%
df['condition_weather'] = df['condition_weather'].fillna(most_frequent)

# %%
# Check for null values in each column
null_values = df.isnull().sum()

# Print the results
print(null_values)
# Out:
# home_team                 0
# away_team                 0
# home_team_code            0
# away_team_code            0
# home_score                0
# away_score                0
# home_penalty             29
# away_penalty             29
# home_score_total          0
# away_score_total          0
# winner                    3
# winner_reason             0
# year                      0
# date                      0
# date_time                 0
# utc_offset_hours          0
# group_name                7
# matchday_name             0
# condition_humidity        0
# condition_pitch           0
# condition_temperature     0
# condition_weather         0
# condition_wind_speed      0
# status                    0
# type                      0
# round                     0
# round_mode                0
# match_attendance          0
# stadium_id                0
# stadium_country_code      0
# stadium_capacity          0
# stadium_latitude          0
# stadium_longitude         0
# stadium_pitch_length      0
# stadium_pitch_width       0
# goals                     2
# penalties_missed         30
# penalties                29
# red_cards                28
# game_referees             0
# stadium_city              0
# stadium_name              0
# stadium_name_media        0
# stadium_name_official     0
# stadium_name_event        0
# stadium_name_sponsor      0
# dtype: int64

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots(1, 2, figsize=(12, 6))

df['away_score'].plot(kind='hist', bins=20, title='away_score', ax=axes[0])
axes[0].spines[['top', 'right']].set_visible(False)

df['home_score'].plot(kind='hist', bins=20, title='home_score', ax=axes[1])
axes[1].spines[['top', 'right']].set_visible(False)

plt.show()

# %%
# pairplot of df
import seaborn as sns

sns.pairplot(df)
plt.show()

# %% [markdown]
# **Heatmaps to visualize the frequency distributions of match conditions like pitch and weather across different categories such as matchday, condition weather, and group name. These visualizations help in understanding how match conditions vary with different groupings.**

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd

fig, axes = plt.subplots(2, 2, figsize=(16, 16))

# First heatmap
df_2dhist_1 = pd.DataFrame({
    x_label: grp['condition_pitch'].value_counts()
    for x_label, grp in df.groupby('matchday_name')
})
sns.heatmap(df_2dhist_1, cmap='viridis', ax=axes[0, 0])
axes[0, 0].set_xlabel('matchday_name')
axes[0, 0].set_ylabel('condition_pitch')
axes[0, 0].set_title('Heatmap 1: matchday_name vs condition_pitch')

# Second heatmap
df_2dhist_2 = pd.DataFrame({
    x_label: grp['condition_weather'].value_counts()
    for x_label, grp in df.groupby('matchday_name')
})
sns.heatmap(df_2dhist_2, cmap='viridis', ax=axes[0, 1])
axes[0, 1].set_xlabel('matchday_name')
axes[0, 1].set_ylabel('condition_weather')
axes[0, 1].set_title('Heatmap 2: matchday_name vs condition_weather')

# Third heatmap
df_2dhist_3 = pd.DataFrame({
    x_label: grp['condition_pitch'].value_counts()
    for x_label, grp in df.groupby('condition_weather')
})
sns.heatmap(df_2dhist_3, cmap='viridis', ax=axes[1, 0])
axes[1, 0].set_xlabel('condition_weather')
axes[1, 0].set_ylabel('condition_pitch')
axes[1, 0].set_title('Heatmap 3: condition_weather vs condition_pitch')

# Fourth heatmap
df_2dhist_4 = pd.DataFrame({
    x_label: grp['condition_weather'].value_counts()
    for x_label, grp in df.groupby('group_name')
})
sns.heatmap(df_2dhist_4, cmap='viridis', ax=axes[1, 1])
axes[1, 1].set_xlabel('group_name')
axes[1, 1].set_ylabel('condition_weather')
axes[1, 1].set_title('Heatmap 4: group_name vs condition_weather')

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# **Horizontal bar plots to visualize the frequency distribution of various match characteristics such as round, winner, winner reason, weather conditions, pitch conditions, and stadium name. These plots help in understanding the distribution of these categorical variables across the dataset.**

# %%
# Create a figure with 2 rows and 2 columns of subplots
fig, axes = plt.subplots(3, 2, figsize=(16, 16))

# Plot each graph on its respective subplot
df.groupby('round').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[0, 0])
df.groupby('winner').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[0, 1])
df.groupby('winner_reason').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[1, 0])
df.groupby('condition_weather').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[1, 1])
df.groupby('condition_pitch').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[2, 0])
df.groupby('stadium_name').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'), ax=axes[2, 1])

# Hide the top and right spines for all subplots
for ax in axes.flat:
    ax.spines[['top', 'right']].set_visible(False)

# Set the x-axis label for all subplots
for ax in axes.flat:
    ax.set_xlabel('frequency')

# Adjust the spacing between subplots
plt.tight_layout()

# %% [markdown]
# **Violin plots to visualize the distribution of home and away scores against various categorical variables such as stadium, matchday, and group. These plots provide insights into the spread and density of scores across different conditions.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


rows = 3
cols = 2

figsize = (12, 2 * len(df['group_name'].unique()))
plt.figure(figsize=figsize)

plot_titles = [
    "Home Score vs Stadium",
    "Away Score vs Stadium",
    "Away Score vs Matchday",
    "Home Score vs Matchday",
    "Away Score vs Group",
    "Home Score vs Group"
]

# Loop through each position in the grid and create a violin plot
count = 1
for i in range(rows):
    for j in range(cols):
        if count > len(plot_titles):
            break

        if count <= 2:
            x_var = (['home_score', 'away_score'][count - 1])
            y_var = 'stadium_name'
            palette = 'Dark2'
        elif count <= 4:
            x_var = 'matchday_name'
            y_var = (['away_score', 'home_score'][count - 3])
            palette = 'viridis'
        else:
            x_var = 'group_name'
            y_var = (['away_score', 'home_score'][count - 5])
            palette = 'inferno'

        # Create the subplot at the current position
        ax = plt.subplot(rows, cols, count)

        # Create the violin plot using seaborn
        sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
        sns.despine(top=True, right=True)

        # Add title for each subplot
        ax.set_title(plot_titles[count - 1], fontsize=10)
        ax.set_xlabel(x_var, fontsize=8)  # Set x-axis label
        ax.set_ylabel(y_var, fontsize=8)  # Set y-axis label
        count += 1

# Adjust layout to prevent overlapping elements
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)
# <ipython-input-33-eac23123791a>:44: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(data=df, x=x_var, y=y_var, inner='quartile', palette=palette, ax=ax)

# %% [markdown]
# **Regression plots to explore the relationships between match attendance, stadium capacity, wind speed, temperature, and humidity. The plots help in understanding how these variables correlate with each other.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axs = plt.subplots(2, 2, figsize=(12, 10))

sns.regplot(x='match_attendance', y='stadium_capacity', data=df, ax=axs[0,0])
axs[0,0].set_title('Regression Plot of Stadium Capacity vs. Attendance')
axs[0,0].set_xlabel('Attendance')
axs[0,0].set_ylabel('Stadium Capacity')

sns.regplot(x='condition_wind_speed', y='condition_temperature', data=df, ax=axs[0,1])
axs[0,1].set_title('Regression Plot of Winner vs. Attendance')
axs[0,1].set_xlabel('Wind Speed')
axs[0,1].set_ylabel('Temperature')

sns.regplot(x='condition_wind_speed', y='condition_humidity', data=df, ax=axs[1,0])
axs[1,0].set_title('Regression Plot of Winner vs. Attendance')
axs[1,0].set_xlabel('Wind Speed')
axs[1,0].set_ylabel('Humidity')

sns.regplot(x='condition_humidity', y='condition_temperature', data=df, ax=axs[1,1])
axs[1,1].set_title('Regression Plot of Winner vs. Attendance')
axs[1,1].set_xlabel('Humidity')
axs[1,1].set_ylabel('Temperature')

plt.tight_layout()

plt.show()

# %% [markdown]
# **This section visualizes the distribution of match data for the columns
# winner, winner_reason, stadium_name, and condition_weather using pie charts. Each pie chart represents the proportion of different categories within these columns, providing insights into the distribution of match outcomes, reasons, venues, and weather conditions.**

# %%
import matplotlib.pyplot as plt

column_names = ['winner', 'winner_reason', 'stadium_name', 'condition_weather']

fig, axes = plt.subplots(2, 2, figsize=(16, 14))

# Loop through each column name and create a pie chart
for i, column_name in enumerate(column_names):
    ax = axes.flat[i]  # Get the current subplot
    df[column_name].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140, ax=ax)
    ax.set_title(f'Proportion of Matches by {column_name}')
    ax.set_ylabel('')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Bar plots to analyze match attendance based on various factors such as home team score, winner, away team score, stadium name, and match round. It also visualizes the total stadium capacity by stadium name.**

# %%
import matplotlib.pyplot as plt
import seaborn as sns


fig, axs = plt.subplots(3, 2, figsize=(16, 14))  # Create a 3x2 grid of subplots

# Define color palettes
inferno_palette = sns.color_palette('inferno', n_colors=10)
plasma_palette = sns.color_palette('plasma', n_colors=10)
viridis_palette = sns.color_palette('viridis', n_colors=10)
dark2_palette = sns.color_palette('Dark2', n_colors=10)

# Plot 1: Match Attendance vs Home Team Score
df.groupby('home_score')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=inferno_palette, ax=axs[0, 0]
)
axs[0, 0].spines[['top', 'right']].set_visible(False)
axs[0, 0].set_xlabel('Home Team Score')
axs[0, 0].set_ylabel('Match Attendance')
axs[0, 0].set_title('Match Attendance vs Home Team Score')

# Plot 2: Match Attendance vs Winner
df.groupby('winner')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=inferno_palette, ax=axs[0, 1]
)
axs[0, 1].spines[['top', 'right']].set_visible(False)
axs[0, 1].set_xlabel('Winner')
axs[0, 1].set_ylabel('Match Attendance')
axs[0, 1].set_title('Match Attendance vs Winner')

# Plot 3: Match Attendance vs Away Team Score
df.groupby('away_score')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=plasma_palette, ax=axs[1, 0]
)
axs[1, 0].spines[['top', 'right']].set_visible(False)
axs[1, 0].set_xlabel('Away Team Score')
axs[1, 0].set_ylabel('Match Attendance')
axs[1, 0].set_title('Match Attendance vs Away Team Score')

# Plot 4: Total Stadium Capacity vs Stadium Name
df.groupby('stadium_name')['stadium_capacity'].sum().sort_values(ascending=False).plot(
    kind='bar', color=viridis_palette, ax=axs[1, 1]
)
axs[1, 1].spines[['top', 'right']].set_visible(False)
axs[1, 1].set_xlabel('Stadium Name')
axs[1, 1].set_ylabel('Total Capacity')
axs[1, 1].set_title('Total Stadium Capacity vs Stadium Name')

# Plot 5: Match Attendance vs Stadium Name
df.groupby('stadium_name')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=dark2_palette, ax=axs[2, 0]
)
axs[2, 0].spines[['top', 'right']].set_visible(False)
axs[2, 0].set_xlabel('Stadium Name')
axs[2, 0].set_ylabel('Match Attendance')
axs[2, 0].set_title('Match Attendance vs Stadium Name')

# Plot 6: Match Attendance vs Round
df.groupby('round')['match_attendance'].sum().sort_values(ascending=False).plot(
    kind='bar', color=inferno_palette, ax=axs[2, 1]
)
axs[2, 1].spines[['top', 'right']].set_visible(False)  # Remove top and right spines
axs[2, 1].set_xlabel('Round')
axs[2, 1].set_ylabel('Match Attendance')
axs[2, 1].set_title('Match Attendance vs Round')

plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# **Swarm Plots to visualize the distributions and relationships between categorical variables in soccer matches. The heatmaps show how pitch conditions and weather vary across different match days, and how weather conditions relate to both pitch conditions and group names, providing insights into potential correlations or patterns in the data.**

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 16))

# Define the parameters for each swarm plot
parameters = [
    {'x': 'home_score', 'y': 'away_score', 'hue': 'winner', 'palette': 'viridis'},
    {'x': 'condition_temperature', 'y': 'condition_humidity', 'hue': 'stadium_name', 'palette': 'plasma'},
    {'x': 'matchday_name', 'y': 'winner', 'hue': 'group_name', 'palette': 'inferno'},
    {'x': 'round', 'y': 'winner', 'hue': 'condition_weather', 'palette': 'Dark2'},
]

for i, parameter in enumerate(parameters):
    ax = axes.flat[i]
    sns.swarmplot(data=df, x=parameter['x'], y=parameter['y'], hue=parameter['hue'], palette=parameter['palette'], ax=ax)
    ax.set_title(f'Swarm Plot of {parameter["y"]} vs. {parameter["x"]}')
    ax.set_xlabel(parameter['x'])
    ax.set_ylabel(parameter['y'])

plt.tight_layout()
plt.show()
